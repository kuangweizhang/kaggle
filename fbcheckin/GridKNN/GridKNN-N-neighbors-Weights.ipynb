# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import time

# %%
feature_list = ['x','y','hour','weekday','day','month','year']

# %%
def prepare_data(df, n_cell_x, n_cell_y):
    #Creating the grid
    size_x = 10. / n_cell_x
    size_y = 10. / n_cell_y
    eps = 0.00001  
    xs = np.where(df.x.values < eps, 0, df.x.values - eps)
    ys = np.where(df.y.values < eps, 0, df.y.values - eps)
    pos_x = (xs / size_x).astype(np.int)
    pos_y = (ys / size_y).astype(np.int)
    df['grid_x'] = pos_x
    df['grid_y'] = pos_y
    
    #Feature engineering
    df.x = df.x.values * fw[0]
    df.y = df.y.values * fw[1]
    initial_date = np.datetime64('2014-01-01T01:01', dtype='datetime64[m]') 
    d_times = pd.DatetimeIndex(initial_date + np.timedelta64(int(mn), 'm') 
                               for mn in df.time.values)    
    df['hour'] = (d_times.hour+ d_times.minute/60) * fw[2]
    df['weekday'] = d_times.weekday * fw[3]
    df['day'] = (d_times.dayofyear * fw[4]).astype(int)
    df['month'] = d_times.month * fw[5]
    df['year'] = (d_times.year - 2013) * fw[6]
    
    return df

# %%
def run_prediction(df_train, df_test, n_cell_x, n_cell_y, th):
    total_result = pd.DataFrame()
    for x_grid in range(0, n_cell_x):
        start_time = time.time()
        for y_grid in range(0, n_cell_y):
            total_result = total_result.append(process_one_cell(df_train, df_test, x_grid, y_grid, th))
        print("Elapsed time overall: %s seconds" % (time.time() - start_time), x_grid, flush = True)
    return total_result

# %%
def process_one_cell(df_train, df_test, grid_x, grid_y, th):
    start_time = time.time()
    
    df_cell_train = df_train[(df_train.grid_x == grid_x)&(df_train.grid_y == grid_y)]
    place_counts = df_cell_train.place_id.value_counts()
    mask = (place_counts[df_cell_train.place_id.values] >= th).values
    df_cell_train = df_cell_train.loc[mask]
    
    df_cell_test = df_test[(df_test.grid_x == grid_x)&(df_test.grid_y == grid_y)]
    row_ids = df_cell_test.row_id
    
    #Applying the classifier
    clf = KNeighborsClassifier(n_neighbors=25, weights='distance', 
                               metric='manhattan')
    clf.fit(df_cell_train[feature_list], df_cell_train.place_id)
    predictions = clf.predict_proba(df_cell_test[feature_list])
    result_index = np.argsort(predictions, axis=1)[:,::-1][:,:3]
    result = pd.DataFrame(df_cell_test.row_id)
    result['p1'] = clf.classes_[result_index][:,:1]
    result['p2'] = clf.classes_[result_index][:,1:2]
    result['p3'] = clf.classes_[result_index][:,2:3]
    
    return result

# %%
def run_validation():
    # Run validation
    df_train = pd.read_csv('../train.csv',
                           usecols=['row_id','x','y','time','place_id'])
    
    df_valiation = df_train[df_train.time > 786239 * 0.875]
    
    df_train = df_train[df_train.time <= 786239 * 0.875]
    
    n_cell_x = 10
    n_cell_y = 20 
    
    print('Preparing train data', flush=True)
    df_train = prepare_data(df_train, n_cell_x, n_cell_y)
    df_valiation = prepare_data(df_valiation, n_cell_x, n_cell_y)
    df_valiation['p1'] = np.nan
    df_valiation['p2'] = np.nan
    df_valiation['p3'] = np.nan
    
    prediction_result = run_prediction(df_train, df_valiation, n_cell_x, n_cell_y, 5)
    
    # Calculate score
    prediction_result.sort_index(inplace=True)
    prediction_result['score'] = (prediction_result.p1 == df_valiation.place_id) * 1
    prediction_result['score'] += (prediction_result.p2 == df_valiation.place_id) * 0.5
    prediction_result['score'] += (prediction_result.p3 == df_valiation.place_id) * 0.33
    
    print(prediction_result.score.describe(), flush=True)

# %%
print('=======base======', flush=True)
#     x    y     hour weekday day     month year
fw = [500, 1000, 4,   3,      1./22., 2,    10]
run_validation()

print('=======y======', flush=True)
#     x    y     hour weekday day     month year
fw = [500, 800, 4,   3,      1./22., 2,    10]
run_validation()

#     x    y     hour weekday day     month year
fw = [500, 900, 4,   3,      1./22., 2,    10]
run_validation()

#     x    y     hour weekday day     month year
fw = [500, 1000, 4,   3,      1./22., 2,    10]
run_validation()

#     x    y     hour weekday day     month year
fw = [500, 1100, 4,   3,      1./22., 2,    10]
run_validation()

#     x    y     hour weekday day     month year
fw = [500, 1200, 4,   3,      1./22., 2,    10]
run_validation()

print('=======x======', flush=True)
#     x    y     hour weekday day     month year
fw = [300, 1200, 4,   3,      1./22., 2,    10]
run_validation()

#     x    y     hour weekday day     month year
fw = [400, 1000, 4,   3,      1./22., 2,    10]
run_validation()

#     x    y     hour weekday day     month year
fw = [500, 1000, 4,   3,      1./22., 2,    10]
run_validation()

#     x    y     hour weekday day     month year
fw = [600, 1000, 4,   3,      1./22., 2,    10]
run_validation()

#     x    y     hour weekday day     month year
fw = [700, 1000, 4,   3,      1./22., 2,    10]
run_validation()

print('=======hour======', flush=True)
#     x    y     hour weekday day     month year
fw = [500, 1000, 3,   3,      1./22., 2,    10]
run_validation()

#     x    y     hour weekday day     month year
fw = [500, 1000, 3.5,   3,      1./22., 2,    10]
run_validation()

#     x    y     hour weekday day     month year
fw = [500, 1000, 4,   3,      1./22., 2,    10]
run_validation()

#     x    y     hour weekday day     month year
fw = [500, 1000, 4.5,   3,      1./22., 2,    10]
run_validation()

#     x    y     hour weekday day     month year
fw = [500, 1000, 5,   3,      1./22., 2,    10]
run_validation()

print('=======weekday======', flush=True)
#     x    y     hour weekday day     month year
fw = [500, 1000, 4,   2,      1./22., 2,    10]
run_validation()

#     x    y     hour weekday day     month year
fw = [500, 1000, 4,   2.5,      1./22., 2,    10]
run_validation()

#     x    y     hour weekday day     month year
fw = [500, 1000, 4,   3,      1./22., 2,    10]
run_validation()

#     x    y     hour weekday day     month year
fw = [500, 1000, 4,   3.5,      1./22., 2,    10]
run_validation()

#     x    y     hour weekday day     month year
fw = [500, 1000, 4,   4,      1./22., 2,    10]
run_validation()

print('=======year======', flush=True)
#     x    y     hour weekday day     month year
fw = [500, 1000, 4,   3,      1./22., 2,    8]
run_validation()

#     x    y     hour weekday day     month year
fw = [500, 1000, 4,   3,      1./22., 2,    9]
run_validation()

#     x    y     hour weekday day     month year
fw = [500, 1000, 4,   3,      1./22., 2,    10]
run_validation()

#     x    y     hour weekday day     month year
fw = [500, 1000, 4,   3,      1./22., 2,    11]
run_validation()

#     x    y     hour weekday day     month year
fw = [500, 1000, 4,   3,      1./22., 2,    12]
run_validation()
# Out:
# =======base======
# min            0.000000
# 25%            0.000000
# 50%            0.500000
# 75%            1.000000
# max            1.000000
# Name: score, dtype: float64
# Preparing train data
# Elapsed time overall: 39.2033257484436 seconds 0
# Elapsed time overall: 40.32588982582092 seconds 1
# Elapsed time overall: 45.1584837436676 seconds 2
# Elapsed time overall: 43.78443431854248 seconds 3
# Elapsed time overall: 43.473472118377686 seconds 4
# Elapsed time overall: 45.67082118988037 seconds 5
# Elapsed time overall: 43.50708746910095 seconds 6
# Elapsed time overall: 44.68258786201477 seconds 7
# Elapsed time overall: 42.904632806777954 seconds 8
# Elapsed time overall: 38.59732747077942 seconds 9
# count    4417684.000000
# mean           0.533813
# std            0.453539
# min            0.000000
# 25%            0.000000
# 50%            0.500000
# 75%            1.000000
# max            1.000000
# Name: score, dtype: float64
# Preparing train data
# Elapsed time overall: 39.5854070186615 seconds 0
# Elapsed time overall: 41.94028925895691 seconds 1
# Elapsed time overall: 46.536088705062866 seconds 2
# Elapsed time overall: 43.149540185928345 seconds 3
# Elapsed time overall: 43.868300914764404 seconds 4
# Elapsed time overall: 45.40001845359802 seconds 5
# Elapsed time overall: 45.08728861808777 seconds 6
# Elapsed time overall: 46.35737991333008 seconds 7
# Elapsed time overall: 43.66655230522156 seconds 8
# Elapsed time overall: 39.086474657058716 seconds 9
# count    4417684.000000
# mean           0.533805
# std            0.453489
# min            0.000000
# 25%            0.000000
# 50%            0.500000
# 75%            1.000000
# max            1.000000
# Name: score, dtype: float64
# Preparing train data
# Elapsed time overall: 40.13064384460449 seconds 0
# Elapsed time overall: 41.91853332519531 seconds 1
# Elapsed time overall: 46.40154790878296 seconds 2
# Elapsed time overall: 43.735228538513184 seconds 3
# Elapsed time overall: 43.703765630722046 seconds 4
# Elapsed time overall: 45.958088874816895 seconds 5
# Elapsed time overall: 43.998857498168945 seconds 6
# Elapsed time overall: 47.20575928688049 seconds 7
# Elapsed time overall: 44.45994544029236 seconds 8
# Elapsed time overall: 40.93716812133789 seconds 9
# count    4417684.000000
# mean           0.533516
# std            0.453427
# min            0.000000
# 25%            0.000000
# 50%            0.500000
# 75%            1.000000
# max            1.000000
# Name: score, dtype: float64
# Preparing train data
# Elapsed time overall: 40.55379867553711 seconds 0
# Elapsed time overall: 42.49768352508545 seconds 1
# Elapsed time overall: 46.09507608413696 seconds 2
# Elapsed time overall: 44.346983671188354 seconds 3
# Elapsed time overall: 45.01685857772827 seconds 4
# Elapsed time overall: 46.07279086112976 seconds 5
# Elapsed time overall: 44.66480302810669 seconds 6
# Elapsed time overall: 47.20587372779846 seconds 7
# Elapsed time overall: 44.81039047241211 seconds 8
# Elapsed time overall: 39.74679899215698 seconds 9
# count    4417684.000000
# mean           0.532999
# std            0.453380
# min            0.000000
# 25%            0.000000
# 50%            0.500000
# 75%            1.000000
# max            1.000000
# Name: score, dtype: float64

# %% [markdown]
# cell x = 20
# cell y = 40
# Validation result:
# 0.532182
#
# cell x = 10
# cell y = 20
# Validation result:
# 0.532963
#
# (d_times.hour+ d_times.minute/60)
# Validation result:
# 0.533805

# %%
# Write to file
prediction_result['place_id'] = prediction_result.p1.astype(str) + " " + \
                                 prediction_result.p2.astype(str) + " " + \
                                 prediction_result.p3.astype(str)
prediction_result[['row_id', 'place_id']].to_csv('validation_result.csv', index=False)

# %%
# Run test
df_train = pd.read_csv('../train.csv',
                       usecols=['row_id','x','y','time','place_id'])
df_test = pd.read_csv('../test.csv',
                       usecols=['row_id','x','y','time'])
n_cell_x = 10
n_cell_y = 20 

df_train = prepare_data(df_train, n_cell_x, n_cell_y)
df_test = prepare_data(df_test, n_cell_x, n_cell_y)
df_test['p1'] = np.nan
df_test['p2'] = np.nan
df_test['p3'] = np.nan
prediction_result = run_prediction(df_train, df_test, 5)

prediction_result.sort_index(inplace=True)
prediction_result['place_id'] = prediction_result.p1.astype(str) + " " + \
                                 prediction_result.p2.astype(str) + " " + \
                                 prediction_result.p3.astype(str)
prediction_result[['row_id', 'place_id']].to_csv('result.csv', index=False)
