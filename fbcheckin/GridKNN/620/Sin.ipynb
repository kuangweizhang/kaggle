# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
import time
from datetime import timedelta
import gc

# Found at: https://www.kaggle.com/rshekhar2/facebook-v-predicting-check-ins/xgboost-cv-example-with-small-bug
def mapkprecision(truthvalues, predictions):
    '''
    This is a faster implementation of MAP@k valid for numpy arrays.
    It is only valid when there is one single truth value. 

    m ~ number of observations
    k ~ MAP at k -- in this case k should equal 3

    truthvalues.shape = (m,) 
    predictions.shape = (m, k)
    '''
    z = (predictions == truthvalues[:, None]).astype(np.float32)
    weights = 1./(np.arange(predictions.shape[1], dtype=np.float32) + 1.)
    z = z * weights[None, :]
    return np.mean(np.sum(z, axis=1))

def load_data(data_name):
    types = {'row_id': np.dtype(np.int32),
         'x': np.dtype(float),
         'y' : np.dtype(float),
         'accuracy': np.dtype(np.int16),
         'place_id': np.int64,
         'time': np.dtype(np.int32)}
    df = pd.read_csv(data_name, dtype=types, index_col = 0, na_filter=False)
    return df

def process_one_cell(df_cell_train, df_cell_test, fw, th, n_neighbors):
    
    # Remove infrequent places
    df_cell_train = remove_infrequent_places(df_cell_train, th).copy()
    
    # Store row_ids for test
    row_ids = df_cell_test.index
    
    # Preparing data
    y = df_cell_train.place_id.values
    X = df_cell_train.drop(['place_id'], axis=1).values
    
    #Applying the classifier
    clf = KNeighborsClassifier(n_neighbors=n_neighbors,
                            weights=calculate_distance, p=1, 
                            n_jobs=2, leaf_size=20)
    clf.fit(X, y)
    y_pred = clf.predict_proba(df_cell_test.values)
    y_pred_labels = np.argsort(y_pred, axis=1)[:,:-4:-1]
    pred_labels = clf.classes_[y_pred_labels]
    cell_pred = np.column_stack((row_ids, pred_labels)).astype(np.int64) 
    
    return cell_pred
    
def calculate_distance(distances):
    return distances ** fw[7]
    
# Generate a dictionary of the time limits so it doesn't have to be 
# recalculated each loop
def create_time_dict(t_cuts, time_factor, time_aug):
    
    t_slice = 24 / t_cuts
    time_dict = dict()
    for t in range(t_cuts):
        
        t_min = 2 * np.pi * (t * t_slice * 12 / 288)
        t_max = 2 * np.pi * (((t + 1) * t_slice * 12 - 1) / 288)
        sin_t_start = np.round(np.sin(t_min)+1, 4) * time_factor
        sin_t_stop = np.round(np.sin(t_max)+1, 4) * time_factor
        cos_t_start = np.round(np.cos(t_min)+1, 4) * time_factor
        cos_t_stop = np.round(np.cos(t_max)+1, 4) * time_factor
        #print(t, (sin_t_start, sin_t_stop, cos_t_start, cos_t_stop))
        sin_t_min = min((sin_t_start, sin_t_stop))
        sin_t_max = max((sin_t_start, sin_t_stop))
        cos_t_min = min((cos_t_start, cos_t_stop))
        cos_t_max = max((cos_t_start, cos_t_stop))

        time_dict[t] = [sin_t_min, sin_t_max, cos_t_min, cos_t_max]
        t_min = 2 * np.pi * ((t * t_slice - time_aug) * 12 / 288)
        t_max = 2 * np.pi * ((((t + 1) * t_slice + time_aug)* 12 - 1) / 288)
        sin_t_start = np.round(np.sin(t_min)+1, 4) * time_factor
        sin_t_stop = np.round(np.sin(t_max)+1, 4) * time_factor
        cos_t_start = np.round(np.cos(t_min)+1, 4) * time_factor
        cos_t_stop = np.round(np.cos(t_max)+1, 4) * time_factor
        sin_t_min = min((sin_t_start, sin_t_stop, sin_t_min))
        sin_t_max = max((sin_t_start, sin_t_stop, sin_t_max))
        cos_t_min = min((cos_t_start, cos_t_stop, cos_t_min))
        cos_t_max = max((cos_t_start, cos_t_stop, cos_t_max))
        time_dict[t] += [sin_t_min, sin_t_max, cos_t_min, cos_t_max]
        
    return time_dict

def process_grid(df_train, df_test, x_cuts, y_cuts, t_cuts,
                 x_border_aug, y_border_aug, time_aug, fw, th, n_neighbors):
    preds_list = []
    x_slice = df_train['x'].max() / x_cuts
    y_slice = df_train['y'].max() / y_cuts
    time_max = df_train['minute_sin'].max()
    time_factor = time_max / 2
    time_dict = create_time_dict(t_cuts, time_factor, time_aug)

    for i in range(x_cuts):
        row_start_time = time.time()
        x_min = x_slice * i
        x_max = x_slice * (i+1)
        x_max += int((i+1) == x_cuts) # expand edge at end

        mask = (df_test['x'] >= x_min)
        mask = mask & (df_test['x'] < x_max)      
        df_col_test = df_test[mask]
        x_min -= x_border_aug
        x_max += x_border_aug
        mask = (df_train['x'] >= x_min)
        mask = mask & (df_train['x'] < x_max)
        df_col_train = df_train[mask]

        for j in range(y_cuts):
            y_min = y_slice * j
            y_max = y_slice * (j+1)
            y_max += int((j+1) == y_cuts) # expand edge at end

            mask = (df_col_test['y'] >= y_min)
            mask= mask & (df_col_test['y'] < y_max)
            df_row_test = df_col_test[mask]
            y_min -= y_border_aug
            y_max += y_border_aug
            mask = (df_col_train['y'] >= y_min)
            mask = mask & (df_col_train['y'] < y_max)
            df_row_train = df_col_train[mask]

            for t in range(t_cuts):
                #print(df_row_test.shape, df_row_train.shape)
                t_lim = time_dict[t]
                mask = df_row_test['minute_sin'].between(t_lim[0], t_lim[1])
                mask = mask & df_row_test['minute_cos'].between(t_lim[2], t_lim[3])
                df_cell_test = df_row_test[mask].copy()
                mask = df_row_train['minute_sin'].between(t_lim[4], t_lim[5])
                mask = mask & df_row_train['minute_cos'].between(t_lim[6], t_lim[7])
                df_cell_train = df_row_train[mask].copy()
                cell_pred = process_one_cell(df_cell_train.copy(), 
                                             df_cell_test.copy(), 
                                             fw, th, n_neighbors)
                preds_list.append(cell_pred)
        elapsed = (time.time() - row_start_time)
        print('Row', i, 'completed in:', timedelta(seconds=elapsed))
    preds = np.vstack(preds_list)
    return preds

# Thank you Alex!
# From: https://www.kaggle.com/drarfc/facebook-v-predicting-check-ins/fastest-way-to-write-the-csv
def generate_submission(preds, file_name):    
    print('Writing submission file')
    print('Pred shape:', preds.shape)
    with open(file_name, "w") as out:
        out.write("row_id,place_id\n")
        rows = ['']*8607230
        n=0
        for num in range(8607230):
            rows[n]='%d,%d %d %d\n' % (preds[num,0],preds[num,1],preds[num,2],preds[num,3])
            n=n+1
        out.writelines(rows)

def validation_split(df, val_start_day):
    day = df['time']//1440
    df_val = df.loc[(day>=val_start_day)].copy()
    df = df.loc[(day<val_start_day)].copy()
    return df, df_val

def remove_infrequent_places(df, th=5):
    place_counts = df.place_id.value_counts()
    mask = (place_counts[df.place_id.values] >= th).values
    df = df.loc[mask]
    return df
    
def prepare_data(datapath, val_start_day):
    val_label = None
    df_train = load_data(datapath + 'train.csv')
    if val_start_day > 0:
        # Create validation data
        df_train, df_test = validation_split(df_train, val_start_day)
        val_label = df_test['place_id']
        df_test.drop(['place_id'], axis=1, inplace=True)
        print('Feature engineering on train')
        df_train = feature_engineering(df_train)
        print('Feature engineering on validation')
        df_test = feature_engineering(df_test)
    else:
        print('Feature engineering on train')
        df_train = feature_engineering(df_train)
        df_test = load_data(datapath + 'test.csv') 
        print('Feature engineering on test')
        df_test = feature_engineering(df_test)
    df_train = apply_weights(df_train, fw)
    df_test = apply_weights(df_test, fw)
    return df_train, df_test, val_label
        

def apply_weights(df, fw):
    df['accuracy'] *= fw[0]
    df['day_of_year_sin'] *= fw[1]
    df['day_of_year_cos'] *= fw[1]
    df['minute_sin'] *= fw[2]
    df['minute_cos'] *= fw[2]
    df['weekday_sin'] *= fw[3]
    df['weekday_cos'] *= fw[3]
    df.x *= fw[4]
    df.y *= fw[5]
    df['year'] *= fw[6]
    return df
    
def feature_engineering(df):
    minute = 2*np.pi*((df["time"]//5)%288)/288
    df['minute_sin'] = (np.sin(minute)+1).round(4)
    df['minute_cos'] = (np.cos(minute)+1).round(4)
    del minute
    day = 2*np.pi*((df['time']//1440)%365)/365
    df['day_of_year_sin'] = (np.sin(day)+1).round(4)
    df['day_of_year_cos'] = (np.cos(day)+1).round(4)
    del day
    weekday = 2*np.pi*((df['time']//1440)%7)/7
    df['weekday_sin'] = (np.sin(weekday)+1).round(4)
    df['weekday_cos'] = (np.cos(weekday)+1).round(4)
    del weekday
    df['year'] = (((df['time'])//525600))
    df.drop(['time'], axis=1, inplace=True)
    df['accuracy'] = np.log10(df['accuracy'])
    return df

# %%
def main(file_name):
    print('Starting...')
    start_time = time.time()
    # Global variables
    datapath = '../../'
    # Change val_start_day to zero to generate predictions
    val_start_day = 0 # Day at which to cut validation
    
    # Defining the size of the grid
    x_cuts = 20 # number of cuts along x 
    y_cuts = 20 # number of cuts along y
    #TODO: More general solution for t_cuts. For now must be 4.
    t_cuts = 4 # number of cuts along time. 
    x_border_aug = 0.04 # expansion of x border on train 
    y_border_aug = 0.015 # expansion of y border on train
    time_aug = 2
    n_neighbors = 37
    
    df_train, df_test, val_label = prepare_data(datapath, val_start_day)
    gc.collect()
    
    elapsed = (time.time() - start_time)
    print('Data prepared in:', timedelta(seconds=elapsed))
        
    preds = process_grid(df_train, df_test, x_cuts, y_cuts, t_cuts,
                         x_border_aug, y_border_aug, time_aug, 
                         fw, th, n_neighbors)
    elapsed = (time.time() - start_time)
    print('Predictions made in:', timedelta(seconds=elapsed))
    
    #del df_train, df_test
    
    if val_start_day > 0:
        preds = preds[preds[:, 0] > 0] # only use rows predicted
        labels = val_label.loc[preds[:, 0]].values
        score = mapkprecision(labels, preds[:, 1:])
        print('Final score:', score)
    else:
        generate_submission(preds, file_name)
    elapsed = (time.time() - start_time)
    print('Task completed in:', timedelta(seconds=elapsed))

# %%
th = 5
fw = [0.6, 0.32935, 0.56515, 0.2670, 22, 52, 0.51785, -2.2]
main('1.csv')

th = 3
fw = [0.6, 0.32935, 0.56515, 0.2670, 22, 52, 0.51785, -2.2]
main('2.csv')

th = 1
fw = [0.6, 0.32935, 0.56515, 0.2670, 22, 52, 0.51785, -2.2]
main('3.csv')
# Out:
# Exception ignored in: 'zmq.backend.cython.message.Frame.__dealloc__'
# Traceback (most recent call last):
#   File "zmq/backend/cython/checkrc.pxd", line 12, in zmq.backend.cython.checkrc._check_rc (zmq\backend\cython\message.c:3968)
# Starting...
# Feature engineering on train
# Feature engineering on test
# Data prepared in: 0:00:54.347217
# Row 0 completed in: 0:00:31.813262
# Row 1 completed in: 0:00:29.618714
# Row 2 completed in: 0:00:29.362926
# Row 3 completed in: 0:00:29.575179
# Row 4 completed in: 0:00:33.294628
# Row 5 completed in: 0:00:37.252659
# Row 6 completed in: 0:00:28.738913
# Row 7 completed in: 0:00:29.407168
# Row 8 completed in: 0:00:28.719248
# Row 9 completed in: 0:00:37.065937
# Row 10 completed in: 0:00:39.793211
# Row 11 completed in: 0:00:37.107537
# Row 12 completed in: 0:00:37.008599
# Row 13 completed in: 0:00:37.269642
# Row 14 completed in: 0:00:40.125840
# Row 15 completed in: 0:00:38.006604
# Row 16 completed in: 0:00:37.322309
# Row 17 completed in: 0:00:32.927039
# Row 18 completed in: 0:00:28.347760
# Row 19 completed in: 0:00:28.871441
# Predictions made in: 0:12:07.032184
# Writing submission file
# Pred shape: (8607230, 4)
# Task completed in: 0:12:37.153056
# Starting...
# Feature engineering on train
# Feature engineering on test
# Data prepared in: 0:01:24.663676
# Row 0 completed in: 0:00:41.409035
# Row 1 completed in: 0:00:41.172586
# Row 2 completed in: 0:00:41.552024
# Row 3 completed in: 0:00:39.328742
# Row 4 completed in: 0:00:41.659779
# Row 5 completed in: 0:00:42.062202
# Row 6 completed in: 0:00:40.010491
# Row 7 completed in: 0:00:39.791949
# Row 8 completed in: 0:00:39.681042
# Row 9 completed in: 0:00:40.291170
# Row 10 completed in: 0:00:42.028565
# Row 11 completed in: 0:00:39.997839
# Row 12 completed in: 0:00:38.465475
# Row 13 completed in: 0:00:30.304346
# Row 14 completed in: 0:00:39.225776
# Row 15 completed in: 0:00:41.266787
# Row 16 completed in: 0:00:39.018632
# Row 17 completed in: 0:00:40.712392
# Row 18 completed in: 0:00:37.180784
# Row 19 completed in: 0:00:35.806350
# Predictions made in: 0:14:36.939194
# Writing submission file
# Pred shape: (8607230, 4)
# Task completed in: 0:15:05.992438
# Starting...
# Feature engineering on train
# Feature engineering on test
# Data prepared in: 0:01:09.137520
# Row 0 completed in: 0:00:36.792331
# Row 1 completed in: 0:00:36.084712
# Row 2 completed in: 0:00:40.657466
# Row 3 completed in: 0:00:47.384328
# Row 4 completed in: 0:00:50.786814
# Row 5 completed in: 0:00:51.700716
# Row 6 completed in: 0:00:49.358453
# Row 7 completed in: 0:00:49.058299
# Row 8 completed in: 0:00:39.065056
# Row 9 completed in: 0:00:39.877456
# Row 10 completed in: 0:00:50.597007
# Row 11 completed in: 0:00:48.908716
# Row 12 completed in: 0:00:48.682861
# Row 13 completed in: 0:00:49.077595
# Row 14 completed in: 0:00:51.767738
# Row 15 completed in: 0:00:49.584878
# Row 16 completed in: 0:00:47.186786
# Row 17 completed in: 0:00:48.587198
# Row 18 completed in: 0:00:45.302825
# Row 19 completed in: 0:00:43.067567
# Predictions made in: 0:16:33.471672
# Writing submission file
# Pred shape: (8607230, 4)
# Task completed in: 0:17:02.219434
# PyErr_CheckSignals()
# KeyboardInterrupt

# %%
th = 0
fw = [0.6, 0.32935, 0.56515, 0.2670, 22, 52, 0.51785, -2.2]
main('4.csv')
# Out:
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:01:04.898172
# Row 0 completed in: 0:00:42.134977
# Row 1 completed in: 0:00:41.088457
# Row 2 completed in: 0:00:44.349375
# Row 3 completed in: 0:00:46.288384
# Row 4 completed in: 0:00:54.735971
# Row 5 completed in: 0:00:54.135906
# Row 6 completed in: 0:00:51.032166
# Row 7 completed in: 0:00:50.095067
# Row 8 completed in: 0:00:50.262805
# Row 9 completed in: 0:00:50.655956
# Row 10 completed in: 0:00:58.676072
# Row 11 completed in: 0:00:50.760745
# Row 12 completed in: 0:00:52.230952
# Row 13 completed in: 0:00:50.601392
# Row 14 completed in: 0:00:58.353522
# Row 15 completed in: 0:00:49.763666
# Row 16 completed in: 0:00:47.491561
# Row 17 completed in: 0:00:47.314151
# Row 18 completed in: 0:00:43.138680
# Row 19 completed in: 0:00:40.473674
# Predictions made in: 0:17:29.472880
# Final score: 0.525622
# Task completed in: 0:17:34.822693

# %%
th = 5
fw = [0.6, 0.32935, 0.56515, 0.2670, 22, 52, 0.51785, -2.2]
fw_old = fw[:]

counter = 4
for i in range(0,len(fw_old)):
    for ratio in [0.9, 0.95, 1.05, 1.1]:
        fw = fw_old[:]
        fw[i] *= ratio
        main(str(counter) + '.csv')
        counter+=1
# Out:
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:01:02.997549
# Row 0 completed in: 0:00:36.655278
# Row 1 completed in: 0:00:34.686817
# Row 2 completed in: 0:00:36.302453
# Row 3 completed in: 0:00:39.045326
# Row 4 completed in: 0:00:40.654633
# Row 5 completed in: 0:00:41.188235
# Row 6 completed in: 0:00:36.797747
# Row 7 completed in: 0:00:36.530125
# Row 8 completed in: 0:00:36.384576
# Row 9 completed in: 0:00:37.707863
# Row 10 completed in: 0:00:40.018156
# Row 11 completed in: 0:00:37.021778
# Row 12 completed in: 0:00:35.551822
# Row 13 completed in: 0:00:35.480202
# Row 14 completed in: 0:00:39.105690
# Row 15 completed in: 0:00:40.812097
# Row 16 completed in: 0:00:38.043835
# Row 17 completed in: 0:00:37.847598
# Row 18 completed in: 0:00:35.276713
# Row 19 completed in: 0:00:33.392251
# Predictions made in: 0:13:32.711383
# Final score: 0.525094
# Task completed in: 0:13:38.344486
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:01:07.943952
# Row 0 completed in: 0:00:44.844627
# Row 1 completed in: 0:00:39.678845
# Row 2 completed in: 0:00:40.139950
# Row 3 completed in: 0:00:39.624008
# Row 4 completed in: 0:00:41.637324
# Row 5 completed in: 0:00:44.670343
# Row 6 completed in: 0:00:39.312347
# Row 7 completed in: 0:00:39.781173
# Row 8 completed in: 0:00:40.061432
# Row 9 completed in: 0:00:41.056945
# Row 10 completed in: 0:00:48.044306
# Row 11 completed in: 0:00:42.803320
# Row 12 completed in: 0:00:41.923025
# Row 13 completed in: 0:00:41.345903
# Row 14 completed in: 0:00:44.127946
# Row 15 completed in: 0:00:43.641731
# Row 16 completed in: 0:00:42.668133
# Row 17 completed in: 0:00:42.586146
# Row 18 completed in: 0:00:41.514100
# Row 19 completed in: 0:00:40.013165
# Predictions made in: 0:15:08.756234
# Final score: 0.525155
# Task completed in: 0:15:15.595431
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:01:10.112190
# Row 0 completed in: 0:00:41.932669
# Row 1 completed in: 0:00:39.791365
# Row 2 completed in: 0:00:40.284046
# Row 3 completed in: 0:00:42.531452
# Row 4 completed in: 0:00:45.211188
# Row 5 completed in: 0:00:45.304917
# Row 6 completed in: 0:00:42.827583
# Row 7 completed in: 0:00:41.546759
# Row 8 completed in: 0:00:40.913076
# Row 9 completed in: 0:00:41.746195
# Row 10 completed in: 0:00:45.184077
# Row 11 completed in: 0:00:41.585915
# Row 12 completed in: 0:00:41.776752
# Row 13 completed in: 0:00:41.018560
# Row 14 completed in: 0:00:44.956101
# Row 15 completed in: 0:00:43.648633
# Row 16 completed in: 0:00:41.348094
# Row 17 completed in: 0:00:43.085997
# Row 18 completed in: 0:00:38.844058
# Row 19 completed in: 0:00:38.527604
# Predictions made in: 0:15:13.615844
# Final score: 0.525224
# Task completed in: 0:15:20.122671
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:01:09.152293
# Row 0 completed in: 0:00:42.049588
# Row 1 completed in: 0:00:40.574570
# Row 2 completed in: 0:00:39.621937
# Row 3 completed in: 0:00:41.349504
# Row 4 completed in: 0:00:43.294916
# Row 5 completed in: 0:00:45.399588
# Row 6 completed in: 0:00:40.944129
# Row 7 completed in: 0:00:40.932575
# Row 8 completed in: 0:00:41.666148
# Row 9 completed in: 0:00:41.741014
# Row 10 completed in: 0:00:47.169209
# Row 11 completed in: 0:00:41.995061
# Row 12 completed in: 0:00:42.768886
# Row 13 completed in: 0:00:42.141740
# Row 14 completed in: 0:00:45.815726
# Row 15 completed in: 0:00:44.004811
# Row 16 completed in: 0:00:41.557347
# Row 17 completed in: 0:00:43.454299
# Row 18 completed in: 0:00:40.645039
# Row 19 completed in: 0:00:39.734320
# Predictions made in: 0:15:17.415044
# Final score: 0.525244
# Task completed in: 0:15:23.959522
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:01:04.537160
# Row 0 completed in: 0:00:34.110913
# Row 1 completed in: 0:00:32.126251
# Row 2 completed in: 0:00:32.059067
# Row 3 completed in: 0:00:32.609472
# Row 4 completed in: 0:00:34.724687
# Row 5 completed in: 0:00:35.786865
# Row 6 completed in: 0:00:34.656133
# Row 7 completed in: 0:00:33.839544
# Row 8 completed in: 0:00:34.410091
# Row 9 completed in: 0:00:34.421878
# Row 10 completed in: 0:00:36.800367
# Row 11 completed in: 0:00:33.346019
# Row 12 completed in: 0:00:34.023040
# Row 13 completed in: 0:00:33.529458
# Row 14 completed in: 0:00:35.675950
# Row 15 completed in: 0:00:34.422867
# Row 16 completed in: 0:00:32.861478
# Row 17 completed in: 0:00:34.147632
# Row 18 completed in: 0:00:32.337300
# Row 19 completed in: 0:00:31.026587
# Predictions made in: 0:12:22.463007
# Final score: 0.526244
# Task completed in: 0:12:27.313607
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:57.729217
# Row 0 completed in: 0:00:34.677109
# Row 1 completed in: 0:00:32.223537
# Row 2 completed in: 0:00:33.294282
# Row 3 completed in: 0:00:34.957836
# Row 4 completed in: 0:00:35.171671
# Row 5 completed in: 0:00:34.582287
# Row 6 completed in: 0:00:32.316484
# Row 7 completed in: 0:00:32.052734
# Row 8 completed in: 0:00:32.378172
# Row 9 completed in: 0:00:33.138122
# Row 10 completed in: 0:00:34.393788
# Row 11 completed in: 0:00:32.077873
# Row 12 completed in: 0:00:32.426147
# Row 13 completed in: 0:00:32.670942
# Row 14 completed in: 0:00:34.393072
# Row 15 completed in: 0:00:33.163018
# Row 16 completed in: 0:00:31.722073
# Row 17 completed in: 0:00:32.265571
# Row 18 completed in: 0:00:30.385966
# Row 19 completed in: 0:00:26.384123
# Predictions made in: 0:11:53.154637
# Final score: 0.525741
# Task completed in: 0:11:56.701441
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:48.630039
# Row 0 completed in: 0:00:32.669390
# Row 1 completed in: 0:00:30.839498
# Row 2 completed in: 0:00:31.026455
# Row 3 completed in: 0:00:32.184411
# Row 4 completed in: 0:00:33.791807
# Row 5 completed in: 0:00:35.165088
# Row 6 completed in: 0:00:32.965137
# Row 7 completed in: 0:00:32.559831
# Row 8 completed in: 0:00:32.999378
# Row 9 completed in: 0:00:33.771350
# Row 10 completed in: 0:00:35.038366
# Row 11 completed in: 0:00:32.416972
# Row 12 completed in: 0:00:32.855901
# Row 13 completed in: 0:00:32.373059
# Row 14 completed in: 0:00:35.001539
# Row 15 completed in: 0:00:33.350703
# Row 16 completed in: 0:00:32.340186
# Row 17 completed in: 0:00:32.610300
# Row 18 completed in: 0:00:30.669464
# Row 19 completed in: 0:00:29.474349
# Predictions made in: 0:11:43.453309
# Final score: 0.524603
# Task completed in: 0:11:47.729848
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:48.197586
# Row 0 completed in: 0:00:26.058189
# Row 1 completed in: 0:00:29.986493
# Row 2 completed in: 0:00:31.340125
# Row 3 completed in: 0:00:31.999971
# Row 4 completed in: 0:00:33.927699
# Row 5 completed in: 0:00:34.835670
# Row 6 completed in: 0:00:32.739724
# Row 7 completed in: 0:00:32.546808
# Row 8 completed in: 0:00:32.808507
# Row 9 completed in: 0:00:33.448030
# Row 10 completed in: 0:00:34.944600
# Row 11 completed in: 0:00:32.578918
# Row 12 completed in: 0:00:32.888018
# Row 13 completed in: 0:00:32.337343
# Row 14 completed in: 0:00:34.972500
# Row 15 completed in: 0:00:33.698014
# Row 16 completed in: 0:00:32.518396
# Row 17 completed in: 0:00:32.679525
# Row 18 completed in: 0:00:31.188048
# Row 19 completed in: 0:00:29.862473
# Predictions made in: 0:11:36.214601
# Final score: 0.524
# Task completed in: 0:11:40.440284
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:49.402804
# Row 0 completed in: 0:00:25.760317
# Row 1 completed in: 0:00:30.339410
# Row 2 completed in: 0:00:30.675489
# Row 3 completed in: 0:00:31.399843
# Row 4 completed in: 0:00:33.409581
# Row 5 completed in: 0:00:34.714314
# Row 6 completed in: 0:00:32.514705
# Row 7 completed in: 0:00:32.400723
# Row 8 completed in: 0:00:32.479702
# Row 9 completed in: 0:00:33.159893
# Row 10 completed in: 0:00:34.636241
# Row 11 completed in: 0:00:32.516597
# Row 12 completed in: 0:00:32.536023
# Row 13 completed in: 0:00:32.325248
# Row 14 completed in: 0:00:34.571857
# Row 15 completed in: 0:00:33.244081
# Row 16 completed in: 0:00:31.338094
# Row 17 completed in: 0:00:32.522763
# Row 18 completed in: 0:00:30.225570
# Row 19 completed in: 0:00:29.314125
# Predictions made in: 0:11:30.139869
# Final score: 0.525038
# Task completed in: 0:11:34.349847
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:50.423797
# Row 0 completed in: 0:00:32.310659
# Row 1 completed in: 0:00:30.469882
# Row 2 completed in: 0:00:30.930600
# Row 3 completed in: 0:00:31.840206
# Row 4 completed in: 0:00:33.246826
# Row 5 completed in: 0:00:34.526300
# Row 6 completed in: 0:00:25.073038
# Row 7 completed in: 0:00:25.484469
# Row 8 completed in: 0:00:25.366347
# Row 9 completed in: 0:00:32.890119
# Row 10 completed in: 0:00:34.421315
# Row 11 completed in: 0:00:32.695674
# Row 12 completed in: 0:00:33.124858
# Row 13 completed in: 0:00:32.444653
# Row 14 completed in: 0:00:34.682057
# Row 15 completed in: 0:00:33.562019
# Row 16 completed in: 0:00:31.855811
# Row 17 completed in: 0:00:32.420877
# Row 18 completed in: 0:00:30.965623
# Row 19 completed in: 0:00:29.594422
# Predictions made in: 0:11:19.041248
# Final score: 0.525127
# Task completed in: 0:11:23.428197
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:55.439091
# Row 0 completed in: 0:00:26.117459
# Row 1 completed in: 0:00:25.518735
# Row 2 completed in: 0:00:30.950651
# Row 3 completed in: 0:00:32.167867
# Row 4 completed in: 0:00:33.359786
# Row 5 completed in: 0:00:34.526142
# Row 6 completed in: 0:00:32.315317
# Row 7 completed in: 0:00:32.120585
# Row 8 completed in: 0:00:32.732709
# Row 9 completed in: 0:00:33.847387
# Row 10 completed in: 0:00:35.244972
# Row 11 completed in: 0:00:32.681489
# Row 12 completed in: 0:00:33.052004
# Row 13 completed in: 0:00:33.004139
# Row 14 completed in: 0:00:35.439117
# Row 15 completed in: 0:00:33.507716
# Row 16 completed in: 0:00:32.680340
# Row 17 completed in: 0:00:32.745573
# Row 18 completed in: 0:00:30.926105
# Row 19 completed in: 0:00:29.746089
# Predictions made in: 0:11:38.771302
# Final score: 0.525233
# Task completed in: 0:11:42.627530
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:48.188850
# Row 0 completed in: 0:00:32.788615
# Row 1 completed in: 0:00:30.503518
# Row 2 completed in: 0:00:31.071387
# Row 3 completed in: 0:00:32.095610
# Row 4 completed in: 0:00:33.723499
# Row 5 completed in: 0:00:34.837630
# Row 6 completed in: 0:00:32.647413
# Row 7 completed in: 0:00:32.222023
# Row 8 completed in: 0:00:32.981110
# Row 9 completed in: 0:00:33.607584
# Row 10 completed in: 0:00:34.916614
# Row 11 completed in: 0:00:32.410203
# Row 12 completed in: 0:00:32.742271
# Row 13 completed in: 0:00:32.794443
# Row 14 completed in: 0:00:34.566629
# Row 15 completed in: 0:00:33.715845
# Row 16 completed in: 0:00:32.331525
# Row 17 completed in: 0:00:32.412626
# Row 18 completed in: 0:00:31.081135
# Row 19 completed in: 0:00:29.443388
# Predictions made in: 0:11:41.849980
# Final score: 0.525215
# Task completed in: 0:11:45.967390
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:50.643716
# Row 0 completed in: 0:00:26.242921
# Row 1 completed in: 0:00:30.025000
# Row 2 completed in: 0:00:30.865212
# Row 3 completed in: 0:00:31.790489
# Row 4 completed in: 0:00:33.696207
# Row 5 completed in: 0:00:34.701966
# Row 6 completed in: 0:00:32.472943
# Row 7 completed in: 0:00:32.293152
# Row 8 completed in: 0:00:33.083899
# Row 9 completed in: 0:00:33.157208
# Row 10 completed in: 0:00:34.589170
# Row 11 completed in: 0:00:32.489409
# Row 12 completed in: 0:00:32.488239
# Row 13 completed in: 0:00:32.123482
# Row 14 completed in: 0:00:34.515808
# Row 15 completed in: 0:00:33.128445
# Row 16 completed in: 0:00:31.463070
# Row 17 completed in: 0:00:32.473118
# Row 18 completed in: 0:00:30.706891
# Row 19 completed in: 0:00:29.468487
# Predictions made in: 0:11:33.036297
# Final score: 0.524966
# Task completed in: 0:11:37.162215
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:48.445876
# Row 0 completed in: 0:00:27.731142
# Row 1 completed in: 0:00:30.012770
# Row 2 completed in: 0:00:30.784432
# Row 3 completed in: 0:00:31.317244
# Row 4 completed in: 0:00:33.561172
# Row 5 completed in: 0:00:34.546838
# Row 6 completed in: 0:00:32.336956
# Row 7 completed in: 0:00:32.041124
# Row 8 completed in: 0:00:24.867822
# Row 9 completed in: 0:00:30.326273
# Row 10 completed in: 0:00:34.303758
# Row 11 completed in: 0:00:32.359290
# Row 12 completed in: 0:00:32.355439
# Row 13 completed in: 0:00:32.204933
# Row 14 completed in: 0:00:26.664496
# Row 15 completed in: 0:00:25.695085
# Row 16 completed in: 0:00:25.126905
# Row 17 completed in: 0:00:29.075763
# Row 18 completed in: 0:00:30.376481
# Row 19 completed in: 0:00:29.369457
# Predictions made in: 0:10:54.148278
# Final score: 0.525114
# Task completed in: 0:10:58.451197
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:53.565232
# Row 0 completed in: 0:00:31.884826
# Row 1 completed in: 0:00:30.921375
# Row 2 completed in: 0:00:31.230363
# Row 3 completed in: 0:00:31.985241
# Row 4 completed in: 0:00:34.062464
# Row 5 completed in: 0:00:35.116733
# Row 6 completed in: 0:00:33.342112
# Row 7 completed in: 0:00:32.433941
# Row 8 completed in: 0:00:32.895720
# Row 9 completed in: 0:00:33.527268
# Row 10 completed in: 0:00:34.679258
# Row 11 completed in: 0:00:32.660364
# Row 12 completed in: 0:00:32.648389
# Row 13 completed in: 0:00:32.690017
# Row 14 completed in: 0:00:34.962185
# Row 15 completed in: 0:00:26.609640
# Row 16 completed in: 0:00:25.870801
# Row 17 completed in: 0:00:25.436952
# Row 18 completed in: 0:00:30.244281
# Row 19 completed in: 0:00:29.676687
# Predictions made in: 0:11:27.095123
# Final score: 0.525261
# Task completed in: 0:11:31.340611
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:49.679321
# Row 0 completed in: 0:00:26.018639
# Row 1 completed in: 0:00:27.329464
# Row 2 completed in: 0:00:31.308232
# Row 3 completed in: 0:00:32.468053
# Row 4 completed in: 0:00:33.954878
# Row 5 completed in: 0:00:34.858195
# Row 6 completed in: 0:00:32.874511
# Row 7 completed in: 0:00:32.463430
# Row 8 completed in: 0:00:32.694205
# Row 9 completed in: 0:00:29.176455
# Row 10 completed in: 0:00:32.051450
# Row 11 completed in: 0:00:32.705879
# Row 12 completed in: 0:00:32.917161
# Row 13 completed in: 0:00:32.579987
# Row 14 completed in: 0:00:35.369155
# Row 15 completed in: 0:00:33.333061
# Row 16 completed in: 0:00:32.155632
# Row 17 completed in: 0:00:32.418504
# Row 18 completed in: 0:00:30.739839
# Row 19 completed in: 0:00:29.429889
# Predictions made in: 0:11:27.180996
# Final score: 0.525296
# Task completed in: 0:11:31.567928
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:52.760492
# Row 0 completed in: 0:00:26.656957
# Row 1 completed in: 0:00:29.914280
# Row 2 completed in: 0:00:31.924495
# Row 3 completed in: 0:00:32.916024
# Row 4 completed in: 0:00:34.550642
# Row 5 completed in: 0:00:35.353756
# Row 6 completed in: 0:00:33.733659
# Row 7 completed in: 0:00:32.958051
# Row 8 completed in: 0:00:33.430712
# Row 9 completed in: 0:00:34.074996
# Row 10 completed in: 0:00:35.422113
# Row 11 completed in: 0:00:32.664948
# Row 12 completed in: 0:00:33.601311
# Row 13 completed in: 0:00:32.466909
# Row 14 completed in: 0:00:35.430592
# Row 15 completed in: 0:00:33.586935
# Row 16 completed in: 0:00:32.080853
# Row 17 completed in: 0:00:26.630862
# Row 18 completed in: 0:00:31.195004
# Row 19 completed in: 0:00:29.945269
# Predictions made in: 0:11:42.017360
# Final score: 0.524967
# Task completed in: 0:11:46.307427
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:54.965599
# Row 0 completed in: 0:00:26.316572
# Row 1 completed in: 0:00:24.874058
# Row 2 completed in: 0:00:28.971469
# Row 3 completed in: 0:00:32.236493
# Row 4 completed in: 0:00:33.425309
# Row 5 completed in: 0:00:35.151317
# Row 6 completed in: 0:00:32.525187
# Row 7 completed in: 0:00:32.226036
# Row 8 completed in: 0:00:32.715958
# Row 9 completed in: 0:00:33.321166
# Row 10 completed in: 0:00:34.528800
# Row 11 completed in: 0:00:32.296535
# Row 12 completed in: 0:00:25.038333
# Row 13 completed in: 0:00:25.551336
# Row 14 completed in: 0:00:26.885412
# Row 15 completed in: 0:00:29.870094
# Row 16 completed in: 0:00:32.315480
# Row 17 completed in: 0:00:32.681279
# Row 18 completed in: 0:00:31.173043
# Row 19 completed in: 0:00:29.970705
# Predictions made in: 0:11:07.684130
# Final score: 0.525108
# Task completed in: 0:11:11.932199
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:54.923424
# Row 0 completed in: 0:00:31.620553
# Row 1 completed in: 0:00:30.278322
# Row 2 completed in: 0:00:30.550621
# Row 3 completed in: 0:00:31.478384
# Row 4 completed in: 0:00:33.017207
# Row 5 completed in: 0:00:34.482584
# Row 6 completed in: 0:00:31.409616
# Row 7 completed in: 0:00:31.491156
# Row 8 completed in: 0:00:31.415651
# Row 9 completed in: 0:00:31.796152
# Row 10 completed in: 0:00:33.427363
# Row 11 completed in: 0:00:31.967565
# Row 12 completed in: 0:00:32.355421
# Row 13 completed in: 0:00:31.495612
# Row 14 completed in: 0:00:27.690767
# Row 15 completed in: 0:00:32.687359
# Row 16 completed in: 0:00:31.247755
# Row 17 completed in: 0:00:32.001524
# Row 18 completed in: 0:00:30.021798
# Row 19 completed in: 0:00:28.634118
# Predictions made in: 0:11:24.644496
# Final score: 0.525221
# Task completed in: 0:11:28.687721
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:43.733932
# Row 0 completed in: 0:00:25.560734
# Row 1 completed in: 0:00:23.862684
# Row 2 completed in: 0:00:28.460143
# Row 3 completed in: 0:00:30.448438
# Row 4 completed in: 0:00:32.932959
# Row 5 completed in: 0:00:34.312331
# Row 6 completed in: 0:00:31.450691
# Row 7 completed in: 0:00:32.106612
# Row 8 completed in: 0:00:31.642652
# Row 9 completed in: 0:00:31.818138
# Row 10 completed in: 0:00:34.185781
# Row 11 completed in: 0:00:26.818701
# Row 12 completed in: 0:00:32.327689
# Row 13 completed in: 0:00:31.323085
# Row 14 completed in: 0:00:33.152984
# Row 15 completed in: 0:00:27.515063
# Row 16 completed in: 0:00:25.872782
# Row 17 completed in: 0:00:31.631259
# Row 18 completed in: 0:00:29.350354
# Row 19 completed in: 0:00:28.577030
# Predictions made in: 0:10:47.749718
# Final score: 0.525163
# Task completed in: 0:10:51.960210
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:47.084259
# Row 0 completed in: 0:00:33.055762
# Row 1 completed in: 0:00:31.066532
# Row 2 completed in: 0:00:31.384760
# Row 3 completed in: 0:00:31.791198
# Row 4 completed in: 0:00:34.237551
# Row 5 completed in: 0:00:34.743546
# Row 6 completed in: 0:00:32.576221
# Row 7 completed in: 0:00:32.334515
# Row 8 completed in: 0:00:32.567785
# Row 9 completed in: 0:00:33.487674
# Row 10 completed in: 0:00:35.229674
# Row 11 completed in: 0:00:25.457573
# Row 12 completed in: 0:00:25.508741
# Row 13 completed in: 0:00:25.586987
# Row 14 completed in: 0:00:32.449572
# Row 15 completed in: 0:00:33.845367
# Row 16 completed in: 0:00:32.164696
# Row 17 completed in: 0:00:32.960013
# Row 18 completed in: 0:00:30.906914
# Row 19 completed in: 0:00:29.665262
# Predictions made in: 0:11:18.825614
# Final score: 0.524836
# Task completed in: 0:11:22.755393
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:49.923083
# Row 0 completed in: 0:00:28.322693
# Row 1 completed in: 0:00:24.483456
# Row 2 completed in: 0:00:24.719701
# Row 3 completed in: 0:00:29.997553
# Row 4 completed in: 0:00:33.326830
# Row 5 completed in: 0:00:34.410666
# Row 6 completed in: 0:00:32.419852
# Row 7 completed in: 0:00:32.030636
# Row 8 completed in: 0:00:32.406067
# Row 9 completed in: 0:00:33.103085
# Row 10 completed in: 0:00:34.237695
# Row 11 completed in: 0:00:25.159084
# Row 12 completed in: 0:00:25.097114
# Row 13 completed in: 0:00:26.455136
# Row 14 completed in: 0:00:34.347431
# Row 15 completed in: 0:00:33.275772
# Row 16 completed in: 0:00:31.745092
# Row 17 completed in: 0:00:32.884243
# Row 18 completed in: 0:00:30.633346
# Row 19 completed in: 0:00:29.132084
# Predictions made in: 0:10:58.773592
# Final score: 0.525073
# Task completed in: 0:11:02.730931
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:45.740858
# Row 0 completed in: 0:00:30.685939
# Row 1 completed in: 0:00:29.831916
# Row 2 completed in: 0:00:30.049578
# Row 3 completed in: 0:00:30.660000
# Row 4 completed in: 0:00:25.858793
# Row 5 completed in: 0:00:26.541216
# Row 6 completed in: 0:00:29.401309
# Row 7 completed in: 0:00:31.837952
# Row 8 completed in: 0:00:27.475847
# Row 9 completed in: 0:00:26.372801
# Row 10 completed in: 0:00:27.230333
# Row 11 completed in: 0:00:25.604078
# Row 12 completed in: 0:00:25.273558
# Row 13 completed in: 0:00:25.151024
# Row 14 completed in: 0:00:27.091379
# Row 15 completed in: 0:00:25.889912
# Row 16 completed in: 0:00:25.128120
# Row 17 completed in: 0:00:25.251615
# Row 18 completed in: 0:00:24.918655
# Row 19 completed in: 0:00:24.168319
# Predictions made in: 0:09:50.767622
# Final score: 0.525268
# Task completed in: 0:09:54.206208
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:57.735434
# Row 0 completed in: 0:00:25.831977
# Row 1 completed in: 0:00:24.405205
# Row 2 completed in: 0:00:24.538127
# Row 3 completed in: 0:00:25.040736
# Row 4 completed in: 0:00:25.447369
# Row 5 completed in: 0:00:25.815008
# Row 6 completed in: 0:00:24.838116
# Row 7 completed in: 0:00:24.630400
# Row 8 completed in: 0:00:25.021526
# Row 9 completed in: 0:00:25.410818
# Row 10 completed in: 0:00:26.469680
# Row 11 completed in: 0:00:25.501285
# Row 12 completed in: 0:00:25.200362
# Row 13 completed in: 0:00:25.501828
# Row 14 completed in: 0:00:26.824390
# Row 15 completed in: 0:00:25.789004
# Row 16 completed in: 0:00:25.490922
# Row 17 completed in: 0:00:25.146594
# Row 18 completed in: 0:00:24.661230
# Row 19 completed in: 0:00:24.303782
# Predictions made in: 0:09:24.211318
# Final score: 0.525276
# Task completed in: 0:09:27.763468
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:43.634433
# Row 0 completed in: 0:00:26.452340
# Row 1 completed in: 0:00:24.742695
# Row 2 completed in: 0:00:25.189029
# Row 3 completed in: 0:00:26.339080
# Row 4 completed in: 0:00:26.100634
# Row 5 completed in: 0:00:26.133329
# Row 6 completed in: 0:00:25.780926
# Row 7 completed in: 0:00:25.731652
# Row 8 completed in: 0:00:26.142451
# Row 9 completed in: 0:00:26.279413
# Row 10 completed in: 0:00:27.503199
# Row 11 completed in: 0:00:25.907264
# Row 12 completed in: 0:00:25.707583
# Row 13 completed in: 0:00:26.036127
# Row 14 completed in: 0:00:27.108066
# Row 15 completed in: 0:00:26.519439
# Row 16 completed in: 0:00:25.958461
# Row 17 completed in: 0:00:25.619543
# Row 18 completed in: 0:00:25.729706
# Row 19 completed in: 0:00:24.936527
# Predictions made in: 0:09:24.133342
# Final score: 0.524652
# Task completed in: 0:09:27.449275
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:42.476080
# Row 0 completed in: 0:00:27.048796
# Row 1 completed in: 0:00:25.414249
# Row 2 completed in: 0:00:25.227701
# Row 3 completed in: 0:00:26.551413
# Row 4 completed in: 0:00:26.395654
# Row 5 completed in: 0:00:26.970602
# Row 6 completed in: 0:00:26.027863
# Row 7 completed in: 0:00:26.223653
# Row 8 completed in: 0:00:25.979471
# Row 9 completed in: 0:00:26.213246
# Row 10 completed in: 0:00:27.108069
# Row 11 completed in: 0:00:25.894198
# Row 12 completed in: 0:00:25.582533
# Row 13 completed in: 0:00:25.811361
# Row 14 completed in: 0:00:27.352248
# Row 15 completed in: 0:00:26.125591
# Row 16 completed in: 0:00:25.922543
# Row 17 completed in: 0:00:25.675382
# Row 18 completed in: 0:00:25.638959
# Row 19 completed in: 0:00:24.872195
# Predictions made in: 0:09:25.080245
# Final score: 0.524948
# Task completed in: 0:09:28.497705
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:42.586199
# Row 0 completed in: 0:00:26.829646
# Row 1 completed in: 0:00:25.396823
# Row 2 completed in: 0:00:25.815940
# Row 3 completed in: 0:00:26.178211
# Row 4 completed in: 0:00:26.513133
# Row 5 completed in: 0:00:26.280921
# Row 6 completed in: 0:00:26.168000
# Row 7 completed in: 0:00:25.586265
# Row 8 completed in: 0:00:25.901209
# Row 9 completed in: 0:00:26.405653
# Row 10 completed in: 0:00:27.542303
# Row 11 completed in: 0:00:26.206704
# Row 12 completed in: 0:00:25.865434
# Row 13 completed in: 0:00:26.003449
# Row 14 completed in: 0:00:27.528242
# Row 15 completed in: 0:00:26.381399
# Row 16 completed in: 0:00:26.001191
# Row 17 completed in: 0:00:25.631916
# Row 18 completed in: 0:00:25.859192
# Row 19 completed in: 0:00:24.652385
# Predictions made in: 0:09:25.910239
# Final score: 0.525401
# Task completed in: 0:09:29.328656
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:42.846056
# Row 0 completed in: 0:00:27.072384
# Row 1 completed in: 0:00:25.479755
# Row 2 completed in: 0:00:25.489979
# Row 3 completed in: 0:00:25.907937
# Row 4 completed in: 0:00:26.524216
# Row 5 completed in: 0:00:27.028127
# Row 6 completed in: 0:00:26.207666
# Row 7 completed in: 0:00:25.794955
# Row 8 completed in: 0:00:26.017447
# Row 9 completed in: 0:00:26.288110
# Row 10 completed in: 0:00:27.760190
# Row 11 completed in: 0:00:26.051565
# Row 12 completed in: 0:00:25.686864
# Row 13 completed in: 0:00:25.875650
# Row 14 completed in: 0:00:27.634030
# Row 15 completed in: 0:00:26.747809
# Row 16 completed in: 0:00:26.681487
# Row 17 completed in: 0:00:25.927221
# Row 18 completed in: 0:00:25.847027
# Row 19 completed in: 0:00:25.472008
# Predictions made in: 0:09:28.917961
# Final score: 0.52556
# Task completed in: 0:09:32.213845
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:42.583028
# Row 0 completed in: 0:00:27.017692
# Row 1 completed in: 0:00:25.381933
# Row 2 completed in: 0:00:25.532250
# Row 3 completed in: 0:00:25.891160
# Row 4 completed in: 0:00:26.241953
# Row 5 completed in: 0:00:26.480535
# Row 6 completed in: 0:00:25.655146
# Row 7 completed in: 0:00:25.721246
# Row 8 completed in: 0:00:25.989725
# Row 9 completed in: 0:00:26.615268
# Row 10 completed in: 0:00:27.329628
# Row 11 completed in: 0:00:26.034235
# Row 12 completed in: 0:00:25.819113
# Row 13 completed in: 0:00:25.820453
# Row 14 completed in: 0:00:27.029061
# Row 15 completed in: 0:00:26.091668
# Row 16 completed in: 0:00:25.828329
# Row 17 completed in: 0:00:25.566319
# Row 18 completed in: 0:00:25.628478
# Row 19 completed in: 0:00:25.499164
# Predictions made in: 0:09:24.331296
# Final score: 0.524838
# Task completed in: 0:09:27.657740
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:42.150428
# Row 0 completed in: 0:00:26.775169
# Row 1 completed in: 0:00:25.253470
# Row 2 completed in: 0:00:25.606118
# Row 3 completed in: 0:00:26.181017
# Row 4 completed in: 0:00:26.646866
# Row 5 completed in: 0:00:26.592830
# Row 6 completed in: 0:00:25.921520
# Row 7 completed in: 0:00:25.913214
# Row 8 completed in: 0:00:26.038299
# Row 9 completed in: 0:00:26.106569
# Row 10 completed in: 0:00:27.362716
# Row 11 completed in: 0:00:26.176610
# Row 12 completed in: 0:00:25.825649
# Row 13 completed in: 0:00:26.342185
# Row 14 completed in: 0:00:27.222151
# Row 15 completed in: 0:00:26.399245
# Row 16 completed in: 0:00:26.030052
# Row 17 completed in: 0:00:25.815790
# Row 18 completed in: 0:00:25.805084
# Row 19 completed in: 0:00:25.014815
# Predictions made in: 0:09:25.757224
# Final score: 0.525035
# Task completed in: 0:09:29.067050
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:42.622574
# Row 0 completed in: 0:00:26.844857
# Row 1 completed in: 0:00:25.245795
# Row 2 completed in: 0:00:25.758908
# Row 3 completed in: 0:00:26.288032
# Row 4 completed in: 0:00:26.210976
# Row 5 completed in: 0:00:26.381188
# Row 6 completed in: 0:00:25.844296
# Row 7 completed in: 0:00:25.690298
# Row 8 completed in: 0:00:26.061011
# Row 9 completed in: 0:00:26.321103
# Row 10 completed in: 0:00:27.102494
# Row 11 completed in: 0:00:26.409677
# Row 12 completed in: 0:00:25.503172
# Row 13 completed in: 0:00:25.925895
# Row 14 completed in: 0:00:27.316179
# Row 15 completed in: 0:00:26.168142
# Row 16 completed in: 0:00:26.214365
# Row 17 completed in: 0:00:25.795902
# Row 18 completed in: 0:00:25.757299
# Row 19 completed in: 0:00:25.359475
# Predictions made in: 0:09:25.391114
# Final score: 0.525345
# Task completed in: 0:09:28.685944
# Starting...
# Feature engineering on train
# Feature engineering on validation
# Data prepared in: 0:00:42.555198
# Row 0 completed in: 0:00:26.969649
# Row 1 completed in: 0:00:25.612857
# Row 2 completed in: 0:00:25.646527
# Row 3 completed in: 0:00:26.175812
# Row 4 completed in: 0:00:26.606057
# Row 5 completed in: 0:00:26.661634
# Row 6 completed in: 0:00:25.753341
# Row 7 completed in: 0:00:26.017360
# Row 8 completed in: 0:00:26.329176
# Row 9 completed in: 0:00:26.419497
# Row 10 completed in: 0:00:27.834227
# Row 11 completed in: 0:00:25.811806
# Row 12 completed in: 0:00:26.118846
# Row 13 completed in: 0:00:26.249608
# Row 14 completed in: 0:00:26.964591
# Row 15 completed in: 0:00:26.145615
# Row 16 completed in: 0:00:25.899133
# Row 17 completed in: 0:00:25.651124
# Row 18 completed in: 0:00:25.677869
# Row 19 completed in: 0:00:24.973986
# Predictions made in: 0:09:26.648328
# Final score: 0.52545
# Task completed in: 0:09:29.935692

# %% [markdown]
# 	Line 26: Final score: 0.525094
# 	Line 53: Final score: 0.525155
# 	Line 80: Final score: 0.525224
# 	Line 107: Final score: 0.525244
# 	Line 134: Final score: 0.526244 <---
# 	Line 161: Final score: 0.525741
# 	Line 188: Final score: 0.524603
# 	Line 215: Final score: 0.524
# 	Line 242: Final score: 0.525038
# 	Line 269: Final score: 0.525127
# 	Line 296: Final score: 0.525233
# 	Line 323: Final score: 0.525215
# 	Line 350: Final score: 0.524966
# 	Line 377: Final score: 0.525114
# 	Line 404: Final score: 0.525261
# 	Line 431: Final score: 0.525296
# 	Line 458: Final score: 0.524967
# 	Line 485: Final score: 0.525108
# 	Line 512: Final score: 0.525221
# 	Line 539: Final score: 0.525163
# 	Line 566: Final score: 0.524836
# 	Line 593: Final score: 0.525073
# 	Line 620: Final score: 0.525268
# 	Line 647: Final score: 0.525276
# 	Line 674: Final score: 0.524652
# 	Line 701: Final score: 0.524948
# 	Line 728: Final score: 0.525401
# 	Line 755: Final score: 0.52556
# 	Line 782: Final score: 0.524838
# 	Line 809: Final score: 0.525035
# 	Line 836: Final score: 0.525345
#         Line 863: Final score: 0.52545  <---

# %%
th = 0
fw = [0.6, 0.32935 * 0.9, 0.56515, 0.2670, 22, 52, 0.51785, -2.2 * 1.1]
main('sinweight.csv')
# Out:
# Starting...
# Feature engineering on train
# Feature engineering on test
# Data prepared in: 0:01:03.955183
# Row 0 completed in: 0:00:41.298077
# Row 1 completed in: 0:00:43.726262
# Row 2 completed in: 0:00:45.563325
# Row 3 completed in: 0:00:47.411692
# Row 4 completed in: 0:00:50.007836
# Row 5 completed in: 0:00:50.784616
# Row 6 completed in: 0:00:48.856702
# Row 7 completed in: 0:00:38.334725
# Row 8 completed in: 0:00:38.332991
# Row 9 completed in: 0:00:44.970773
# Row 10 completed in: 0:00:51.737812
# Row 11 completed in: 0:00:49.102713
# Row 12 completed in: 0:00:48.471685
# Row 13 completed in: 0:00:48.690373
# Row 14 completed in: 0:00:51.496988
# Row 15 completed in: 0:00:48.750929
# Row 16 completed in: 0:00:47.321821
# Row 17 completed in: 0:00:48.120613
# Row 18 completed in: 0:00:44.637181
# Row 19 completed in: 0:00:41.798085
# Predictions made in: 0:16:34.199941
# Writing submission file
# Pred shape: (8607230, 4)
# Task completed in: 0:17:01.961670
