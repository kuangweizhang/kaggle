# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import time

# %%
feature_list = ['x','y','w0','w1','w2','w3','w4','w5','w6','day','month','year', 'accuracy']
for i in range(0,24):
    feature_list.append('h' + str(i))

# %%
def prepare_data(df):    
    #Feature engineering
    df.x = df.x.values * fw[0]
    df.y = df.y.values * fw[1]
    initial_date = np.datetime64('2014-01-02T01:01', dtype='datetime64[m]') 
    d_times = pd.DatetimeIndex(initial_date + np.timedelta64(int(mn), 'm') 
                               for mn in df.time.values)    
    #df['hour'] = (d_times.hour+ d_times.minute/60) * fw[2]
    for i in range(0,24):
        df['h' + str(i)] = (((d_times.hour+ d_times.minute/60) + i) % 24) * fw[2]
    
    df['w0'] = ((d_times.weekday + 0) % 7) * fw[3]
    df['w1'] = ((d_times.weekday + 1) % 7) * fw[3]
    df['w2'] = ((d_times.weekday + 2) % 7) * fw[3]
    df['w3'] = ((d_times.weekday + 3) % 7) * fw[3]
    df['w4'] = ((d_times.weekday + 4) % 7) * fw[3]
    df['w5'] = ((d_times.weekday + 5) % 7) * fw[3]
    df['w6'] = ((d_times.weekday + 6) % 7) * fw[3]
    
    df['day'] = (d_times.dayofyear * fw[4]).astype(int)
    df['month'] = d_times.month * fw[5]
    df['year'] = (d_times.year - 2013) * fw[6]
    #df.accuracy = df.accuracy.values * fw[7]
    df['accuracy'] = np.log10(df.accuracy) * fw[7]
    df['log_month'] = np.log10(3+df.time/(60 * 24 * 30)) * fw[8]
    df = df.drop(['time'], axis=1)
    
    return df

# %%
def calculate_distance(distances):
    return distances ** fw[10]

# %%
def process_one_cell(df_train, df_test, th):    
    place_counts = df_train.place_id.value_counts()
    mask = (place_counts[df_train.place_id.values] >= th).values
    df_train = df_train.loc[mask]
    row_ids = df_test.row_id
    
    best_k=np.floor(np.sqrt(len(df_train.index)/4*fw[9])/5)
    
    #Applying the classifier
    clf = KNeighborsClassifier(n_neighbors=best_k.astype(int), weights=calculate_distance, 
                               metric='manhattan')
    clf.fit(df_train[feature_list], df_train.place_id)
    predictions = clf.predict_proba(df_test[feature_list])
    result_index = np.argsort(predictions, axis=1)[:,::-1][:,:3]
    result = pd.DataFrame(df_test.row_id)
    result['p1'] = clf.classes_[result_index][:,:1]
    result['p2'] = clf.classes_[result_index][:,1:2]
    result['p3'] = clf.classes_[result_index][:,2:3]
    
    return result

# %%
def run_prediction(df_train, df_test):
    df_train = prepare_data(df_train)
    df_test = prepare_data(df_test)
    df_test['p1'] = np.nan
    df_test['p2'] = np.nan
    df_test['p3'] = np.nan
    
    prediction_result = process_one_cell(df_train, df_test, 1)
    prediction_result.sort_index(inplace=True)
    return prediction_result

# %%
def run_one_cell(n_cell_x, n_cell_y, x_index, y_index, x_length, y_length, df):
    min_x = x_index * x_length
    max_x = (x_index + 1) * x_length
    min_y = y_index * y_length
    max_y = (y_index + 1) * y_length
    
    # include the edge
    if(y_index + 1 == n_cell_y):
        max_y += 0.1
    if(x_index + 1 == n_cell_x):
        max_x += 0.1
    df_train_cell = df[(df.time <= 786239 * 0.875) & \
                       (df.x >= min_x - 0.1) & \
                       (df.x < max_x + 0.1) & \
                       (df.y >= min_y - 0.1) & \
                       (df.y < max_y + 0.1)].copy()
    df_validation_cell = df[(df.time > 786239 * 0.875) & \
                            (df.x >= min_x) & \
                            (df.x < max_x) & \
                            (df.y >= min_y) & \
                            (df.y < max_y)].copy()
     
    prediction_result = run_prediction(df_train_cell, df_validation_cell)
     
    # Calculate score
    prediction_result.sort_index(inplace=True)
    prediction_result['score'] = (prediction_result.p1 == df_validation_cell.place_id) * 1
    prediction_result['score'] += (prediction_result.p2 == df_validation_cell.place_id) * 0.5
    prediction_result['score'] += (prediction_result.p3 == df_validation_cell.place_id) * 0.33
    score = prediction_result.score.mean()
    
    return score

# %%
def run_validation():
    df = pd.read_csv('../../train.csv',
                               usecols=['row_id','x','y','accuracy','time','place_id'])
    
    n_cell_x = 10
    n_cell_y = 20
    x_length = 10 / n_cell_x
    y_length = 10 / n_cell_y
    total_score = 0
    score_count = 0
    base_fw = [400, 1000, 1/10.5, 1/2.0, 1./22., 2, 9, 23, 4.5, 0.6, -2]
    global fw_final
    global fw
    
    for x_index in range(0, n_cell_x):
        start_time = time.time()
        for y_index in range(0, n_cell_y):
            fw = base_fw[:]
            score = run_one_cell(n_cell_x, n_cell_y, x_index, y_index, x_length, y_length, df)
            
            if(score < 0.5484):
                print('adjusting weight on ', x_index, y_index, ' with score ', score, flush=True)
                
                adjust_fw = base_fw[:]
                for i in range(0,len(base_fw)):
                    max_score = 0
                    max_score_weight = 0
                    for ratio in [-0.1, -0.05, 0.05, 0.1]:
                        fw = base_fw[:]
                        fw[i] = fw[i] * (1+ratio)
                        temp_score = run_one_cell(n_cell_x, n_cell_y, x_index, y_index, x_length, y_length, df)
                        if(temp_score> max_score):
                            max_score = temp_score
                            max_score_weight = fw[i]
                    
                    if(max_score > score):
                        print('Found new weight imporved the socre to ', max_score, 'with weight', max_score_weight, 'on feature ', i, flush=True)
                        adjust_fw[i] = max_score_weight
                        
                fw_final.append(adjust_fw)
            else:
                fw_final.append(fw)
            print("Cell is done", x_index, y_index, flush=True)
            total_score += score
            score_count += 1
            
        print("Elapsed time overall: %s seconds" % (time.time() - start_time), x_index, flush = True)
    print("Final:", total_score/score_count, flush=True)
    return fw_final

# %%
fw = []
fw_final = []
fw_final = run_validation()
print(fw_final, flush=True)
# Out:
# Cell is done 0 0
# Cell is done 0 1
# Cell is done 0 2
# Cell is done 0 3
# adjusting weight on  0 4  with score  0.5451112028058555
# Found new weight imporved the socre to  0.545281617495354 with weight 360.0 on feature  0
# Found new weight imporved the socre to  0.5453261811429713 with weight 0.05 on feature  4
# Found new weight imporved the socre to  0.5453340210439408 with weight 20.7 on feature  7
# Found new weight imporved the socre to  0.5452267381885664 with weight 0.57 on feature  9
# Found new weight imporved the socre to  0.5451235815968603 with weight -2.1 on feature  10
# Cell is done 0 4
# Cell is done 0 5
# Cell is done 0 6
# Cell is done 0 7
# Cell is done 0 8
# Cell is done 0 9
# Cell is done 0 10
# Cell is done 0 11
# Cell is done 0 12
# Cell is done 0 13
# Cell is done 0 14
# Cell is done 0 15
# Cell is done 0 16
# Cell is done 0 17
# Cell is done 0 18
# Cell is done 0 19
# Elapsed time overall: 1135.6765894889832 seconds 0
# Cell is done 1 0
# Cell is done 1 1
# adjusting weight on  1 2  with score  0.5409229194771319
# Found new weight imporved the socre to  0.5418811927245618 with weight 440.00000000000006 on feature  0
# Found new weight imporved the socre to  0.5418165325394195 with weight 1100.0 on feature  1
# Found new weight imporved the socre to  0.5419909754849469 with weight 0.09047619047619046 on feature  2
# Found new weight imporved the socre to  0.5416546494859703 with weight 0.45 on feature  3
# Found new weight imporved the socre to  0.5417672233334839 with weight 0.04090909090909091 on feature  4
# Found new weight imporved the socre to  0.541211796994925 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.5413266967483791 with weight 8.549999999999999 on feature  6
# Found new weight imporved the socre to  0.5416234823463696 with weight 24.150000000000002 on feature  7
# Found new weight imporved the socre to  0.5418197888077362 with weight 0.66 on feature  9
# Found new weight imporved the socre to  0.5409852537563337 with weight -2.2 on feature  10
# Cell is done 1 2
# Cell is done 1 3
# adjusting weight on  1 4  with score  0.5145208351533114
# Found new weight imporved the socre to  0.5151100725080767 with weight 360.0 on feature  0
# Found new weight imporved the socre to  0.5146147462217135 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.5150428059753607 with weight 0.1 on feature  2
# Found new weight imporved the socre to  0.5149803441949816 with weight 0.45 on feature  3
# Found new weight imporved the socre to  0.5147942692408451 with weight 0.04772727272727273 on feature  4
# Found new weight imporved the socre to  0.5149641827553031 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.515168603127453 with weight 9.450000000000001 on feature  6
# Found new weight imporved the socre to  0.5146597361754132 with weight 21.849999999999998 on feature  7
# Found new weight imporved the socre to  0.5147623831571552 with weight 0.54 on feature  9
# Found new weight imporved the socre to  0.5147213243644584 with weight -2.2 on feature  10
# Cell is done 1 4
# Cell is done 1 5
# adjusting weight on  1 6  with score  0.534155590491159
# Found new weight imporved the socre to  0.5346562812633947 with weight 420.0 on feature  0
# Found new weight imporved the socre to  0.5344500023819694 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.534533371444901 with weight 0.09047619047619046 on feature  2
# Found new weight imporved the socre to  0.5346086417988624 with weight 0.45 on feature  3
# Found new weight imporved the socre to  0.5349983326187374 with weight 0.05 on feature  4
# Found new weight imporved the socre to  0.5348149206802877 with weight 2.1 on feature  5
# Found new weight imporved the socre to  0.5346519937115869 with weight 8.1 on feature  6
# Found new weight imporved the socre to  0.5351207660425858 with weight 21.849999999999998 on feature  7
# Found new weight imporved the socre to  0.5346429422133255 with weight 0.66 on feature  9
# Found new weight imporved the socre to  0.534254204182741 with weight -1.9 on feature  10
# Cell is done 1 6
# adjusting weight on  1 7  with score  0.5469139177168233
# Found new weight imporved the socre to  0.54712055226093 with weight 440.00000000000006 on feature  0
# Found new weight imporved the socre to  0.5471928280207522 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.5472020941438064 with weight 0.10476190476190476 on feature  2
# Found new weight imporved the socre to  0.546930133432168 with weight 0.55 on feature  3
# Found new weight imporved the socre to  0.5471988510007373 with weight 0.04772727272727273 on feature  4
# Found new weight imporved the socre to  0.5471691994069641 with weight 1.9 on feature  5
# Found new weight imporved the socre to  0.5470510563380242 with weight 20.7 on feature  7
# Found new weight imporved the socre to  0.5471942179392102 with weight 0.63 on feature  9
# Found new weight imporved the socre to  0.5470459599703444 with weight -2.2 on feature  10
# Cell is done 1 7
# adjusting weight on  1 8  with score  0.5029728289824151
# Found new weight imporved the socre to  0.5030396667796739 with weight 440.00000000000006 on feature  0
# Found new weight imporved the socre to  0.5030290114786615 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.5029742819780078 with weight 0.09047619047619046 on feature  2
# Found new weight imporved the socre to  0.5033050806412518 with weight 0.525 on feature  3
# Found new weight imporved the socre to  0.5036019760740024 with weight 0.05 on feature  4
# Found new weight imporved the socre to  0.5031263621833644 with weight 1.9 on feature  5
# Found new weight imporved the socre to  0.503215479246376 with weight 24.150000000000002 on feature  7
# Found new weight imporved the socre to  0.503390807381214 with weight 0.54 on feature  9
# Found new weight imporved the socre to  0.5032149949145118 with weight -2.1 on feature  10
# Cell is done 1 8
# adjusting weight on  1 9  with score  0.5215326184092898
# Found new weight imporved the socre to  0.5219749776586197 with weight 950.0 on feature  1
# Found new weight imporved the socre to  0.5220658325886167 with weight 0.1 on feature  2
# Found new weight imporved the socre to  0.5217183000695024 with weight 0.04090909090909091 on feature  4
# Found new weight imporved the socre to  0.5215753152616381 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.5218558236520661 with weight 20.7 on feature  7
# Found new weight imporved the socre to  0.5219005064045237 with weight 0.63 on feature  9
# Found new weight imporved the socre to  0.5217972395988439 with weight -2.1 on feature  10
# Cell is done 1 9
# adjusting weight on  1 10  with score  0.5464584372402291
# Found new weight imporved the socre to  0.5466234413965051 with weight 360.0 on feature  0
# Found new weight imporved the socre to  0.5464738154613431 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.5467826267664136 with weight 0.55 on feature  3
# Found new weight imporved the socre to  0.5466109725685749 with weight 2.1 on feature  5
# Found new weight imporved the socre to  0.5469908561928476 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5464954280964219 with weight 25.3 on feature  7
# Found new weight imporved the socre to  0.5467901080631717 with weight 0.66 on feature  9
# Found new weight imporved the socre to  0.5466525353283421 with weight -2.2 on feature  10
# Cell is done 1 10
# Cell is done 1 11
# adjusting weight on  1 12  with score  0.5378697342493436
# Found new weight imporved the socre to  0.5380050061245101 with weight 0.45 on feature  3
# Found new weight imporved the socre to  0.5379853011663165 with weight 1.9 on feature  5
# Found new weight imporved the socre to  0.5381456036640532 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5379059487671047 with weight 25.3 on feature  7
# Cell is done 1 12
# adjusting weight on  1 13  with score  0.5137105129076047
# Found new weight imporved the socre to  0.5140633491847786 with weight 380.0 on feature  0
# Found new weight imporved the socre to  0.5143839164402134 with weight 0.09047619047619046 on feature  2
# Found new weight imporved the socre to  0.5138650645380395 with weight 0.525 on feature  3
# Found new weight imporved the socre to  0.5139894701086916 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.5137542459239091 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5142404042119525 with weight 25.3 on feature  7
# Found new weight imporved the socre to  0.5141614300271699 with weight 0.66 on feature  9
# Found new weight imporved the socre to  0.5138795006793437 with weight -1.9 on feature  10
# Cell is done 1 13
# adjusting weight on  1 14  with score  0.5394763606377091
# Found new weight imporved the socre to  0.5398932563679639 with weight 360.0 on feature  0
# Found new weight imporved the socre to  0.5400054975261095 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.5395226314824958 with weight 0.1 on feature  2
# Found new weight imporved the socre to  0.5397988821696864 with weight 0.55 on feature  3
# Found new weight imporved the socre to  0.5399404434671026 with weight 0.04772727272727273 on feature  4
# Found new weight imporved the socre to  0.539726498075862 with weight 2.2 on feature  5
# Found new weight imporved the socre to  0.5397608576140698 with weight 8.549999999999999 on feature  6
# Found new weight imporved the socre to  0.5397585669781894 with weight 20.7 on feature  7
# Found new weight imporved the socre to  0.539822704782844 with weight 0.57 on feature  9
# Found new weight imporved the socre to  0.5397223749312771 with weight -2.1 on feature  10
# Cell is done 1 14
# adjusting weight on  1 15  with score  0.5196218258295646
# Found new weight imporved the socre to  0.5200428415641027 with weight 420.0 on feature  0
# Found new weight imporved the socre to  0.5200907462221491 with weight 1050.0 on feature  1
# Found new weight imporved the socre to  0.5197912447421679 with weight 0.1 on feature  2
# Found new weight imporved the socre to  0.5201242405359051 with weight 0.45 on feature  3
# Found new weight imporved the socre to  0.5200229786571078 with weight 0.05 on feature  4
# Found new weight imporved the socre to  0.5201238510671407 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.5202878174170393 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5199626109985941 with weight 20.7 on feature  7
# Found new weight imporved the socre to  0.5198668016825012 with weight 0.63 on feature  9
# Found new weight imporved the socre to  0.5198099392428689 with weight -2.1 on feature  10
# Cell is done 1 15
# Cell is done 1 16
# Cell is done 1 17
# adjusting weight on  1 18  with score  0.5146341463414593
# Found new weight imporved the socre to  0.5146519638897648 with weight 0.09047619047619046 on feature  2
# Found new weight imporved the socre to  0.5146745327842848 with weight 0.525 on feature  3
# Found new weight imporved the socre to  0.5148689420335721 with weight 0.04772727272727273 on feature  4
# Found new weight imporved the socre to  0.5148851757998059 with weight 1.9 on feature  5
# Found new weight imporved the socre to  0.5150364269876424 with weight 25.3 on feature  7
# Found new weight imporved the socre to  0.5147557016154537 with weight 0.57 on feature  9
# Cell is done 1 18
# adjusting weight on  1 19  with score  0.532567182035704
# Found new weight imporved the socre to  0.5328175041413545 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.5328092214246234 with weight 0.525 on feature  3
# Found new weight imporved the socre to  0.5327181115405815 with weight 0.05 on feature  4
# Found new weight imporved the socre to  0.532816123688566 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5327047671636259 with weight -2.1 on feature  10
# Cell is done 1 19
# Elapsed time overall: 10585.67793750763 seconds 1
# Cell is done 2 0
# Cell is done 2 1
# adjusting weight on  2 2  with score  0.5483147769136267
# Found new weight imporved the socre to  0.5486962750716293 with weight 440.00000000000006 on feature  0
# Found new weight imporved the socre to  0.5485313139582441 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.5486160458452682 with weight 0.525 on feature  3
# Found new weight imporved the socre to  0.5486397871469465 with weight 2.1 on feature  5
# Found new weight imporved the socre to  0.5484375767498937 with weight 9.450000000000001 on feature  6
# Found new weight imporved the socre to  0.5486655751125625 with weight 25.3 on feature  7
# Found new weight imporved the socre to  0.5483548915268073 with weight 0.63 on feature  9
# Found new weight imporved the socre to  0.5486672124437127 with weight -1.8 on feature  10
# Cell is done 2 2
# adjusting weight on  2 3  with score  0.520736338599793
# Found new weight imporved the socre to  0.5211088563559896 with weight 420.0 on feature  0
# Found new weight imporved the socre to  0.5209122094989571 with weight 1050.0 on feature  1
# Found new weight imporved the socre to  0.5209073778808482 with weight 0.08571428571428572 on feature  2
# Found new weight imporved the socre to  0.521076001352849 with weight 0.475 on feature  3
# Found new weight imporved the socre to  0.521163936802431 with weight 0.04318181818181818 on feature  4
# Found new weight imporved the socre to  0.5209648741363442 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.5210397642170322 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5210392810552213 with weight 20.7 on feature  7
# Found new weight imporved the socre to  0.5210673044402531 with weight 0.54 on feature  9
# Found new weight imporved the socre to  0.5210639223075766 with weight -2.2 on feature  10
# Cell is done 2 3
# adjusting weight on  2 4  with score  0.5427699717214529
# Found new weight imporved the socre to  0.5432361258395157 with weight 440.00000000000006 on feature  0
# Found new weight imporved the socre to  0.5427925061859279 with weight 1050.0 on feature  1
# Found new weight imporved the socre to  0.543051431601269 with weight 0.475 on feature  3
# Found new weight imporved the socre to  0.5428419936373241 with weight 0.04772727272727273 on feature  4
# Found new weight imporved the socre to  0.543077500883701 with weight 2.1 on feature  5
# Found new weight imporved the socre to  0.5428035524920433 with weight 8.1 on feature  6
# Found new weight imporved the socre to  0.5429334570519583 with weight 21.849999999999998 on feature  7
# Found new weight imporved the socre to  0.5428282962177413 with weight 0.63 on feature  9
# Cell is done 2 4
# Cell is done 2 5
# Cell is done 2 6
# Cell is done 2 7
# Cell is done 2 8
# adjusting weight on  2 9  with score  0.5436125916814685
# Found new weight imporved the socre to  0.5445310008655603 with weight 440.00000000000006 on feature  0
# Found new weight imporved the socre to  0.5445624345132302 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.544233520112975 with weight 0.08571428571428572 on feature  2
# Found new weight imporved the socre to  0.5439228281171661 with weight 0.45 on feature  3
# Found new weight imporved the socre to  0.5440863741970715 with weight 0.04318181818181818 on feature  4
# Found new weight imporved the socre to  0.5443168876133166 with weight 1.9 on feature  5
# Found new weight imporved the socre to  0.5447492141588043 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5444503667258855 with weight 20.7 on feature  7
# Found new weight imporved the socre to  0.5442444535556428 with weight 0.54 on feature  9
# Found new weight imporved the socre to  0.5437018814632552 with weight -2.2 on feature  10
# Cell is done 2 9
# adjusting weight on  2 10  with score  0.5283233587232461
# Found new weight imporved the socre to  0.5284181175190386 with weight 380.0 on feature  0
# Found new weight imporved the socre to  0.5285282916213238 with weight 950.0 on feature  1
# Found new weight imporved the socre to  0.5283995284729741 with weight 0.55 on feature  3
# Found new weight imporved the socre to  0.5288828436706527 with weight 0.04318181818181818 on feature  4
# Found new weight imporved the socre to  0.5287391186071779 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.5284838592673158 with weight 24.150000000000002 on feature  7
# Found new weight imporved the socre to  0.5287481864345266 with weight 0.57 on feature  9
# Found new weight imporved the socre to  0.5286869785999238 with weight -2.1 on feature  10
# Cell is done 2 10
# Cell is done 2 11
# adjusting weight on  2 12  with score  0.5423788337750813
# Found new weight imporved the socre to  0.5427342862552025 with weight 380.0 on feature  0
# Found new weight imporved the socre to  0.5428956834532335 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.5431810867095758 with weight 0.1 on feature  2
# Found new weight imporved the socre to  0.5434811624384663 with weight 0.45 on feature  3
# Found new weight imporved the socre to  0.5433093525179817 with weight 0.05 on feature  4
# Found new weight imporved the socre to  0.5427418591442597 with weight 2.2 on feature  5
# Found new weight imporved the socre to  0.5427598447557705 with weight 8.549999999999999 on feature  6
# Found new weight imporved the socre to  0.5433344377129837 with weight 20.7 on feature  7
# Found new weight imporved the socre to  0.5429136690647443 with weight 0.54 on feature  9
# Found new weight imporved the socre to  0.5424914804998068 with weight -2.2 on feature  10
# Cell is done 2 12
# adjusting weight on  2 13  with score  0.5449672190857731
# Found new weight imporved the socre to  0.5453551265707485 with weight 1050.0 on feature  1
# Found new weight imporved the socre to  0.5449927153523912 with weight 0.08571428571428572 on feature  2
# Found new weight imporved the socre to  0.5450364232380223 with weight 0.525 on feature  3
# Found new weight imporved the socre to  0.5451557093425569 with weight 0.04318181818181818 on feature  4
# Found new weight imporved the socre to  0.5452941176470552 with weight 2.1 on feature  5
# Found new weight imporved the socre to  0.545148879985427 with weight 8.1 on feature  6
# Found new weight imporved the socre to  0.5452048807138918 with weight 25.3 on feature  7
# Found new weight imporved the socre to  0.5450437078856274 with weight -2.1 on feature  10
# Cell is done 2 13
# adjusting weight on  2 14  with score  0.5036889097744323
# Found new weight imporved the socre to  0.5042929767600781 with weight 440.00000000000006 on feature  0
# Found new weight imporved the socre to  0.5047107826384104 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.5041972829801739 with weight 0.08571428571428572 on feature  2
# Found new weight imporved the socre to  0.5043839712918621 with weight 0.475 on feature  3
# Found new weight imporved the socre to  0.5042194976076516 with weight 0.04090909090909091 on feature  4
# Found new weight imporved the socre to  0.5041635338345826 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.5041870300751841 with weight 9.450000000000001 on feature  6
# Found new weight imporved the socre to  0.5047385509227574 with weight 25.3 on feature  7
# Found new weight imporved the socre to  0.5042032638414179 with weight 0.54 on feature  9
# Found new weight imporved the socre to  0.5040174299384788 with weight -2.2 on feature  10
# Cell is done 2 14
# adjusting weight on  2 15  with score  0.5427588908036935
# Found new weight imporved the socre to  0.5432351558828099 with weight 440.00000000000006 on feature  0
# Found new weight imporved the socre to  0.5428266489111664 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.5429218235939175 with weight 0.09047619047619046 on feature  2
# Found new weight imporved the socre to  0.5430201315995575 with weight 0.475 on feature  3
# Found new weight imporved the socre to  0.5430686981043359 with weight 0.04772727272727273 on feature  4
# Found new weight imporved the socre to  0.542784349052166 with weight 2.1 on feature  5
# Found new weight imporved the socre to  0.542784349052166 with weight 8.549999999999999 on feature  6
# Found new weight imporved the socre to  0.5430005483315018 with weight -2.1 on feature  10
# Cell is done 2 15
# adjusting weight on  2 16  with score  0.5351274290476777
# Found new weight imporved the socre to  0.5351989296837263 with weight 380.0 on feature  0
# Found new weight imporved the socre to  0.5355529236302983 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.5352291968241396 with weight 0.09047619047619046 on feature  2
# Found new weight imporved the socre to  0.5353388603763612 with weight 0.475 on feature  3
# Found new weight imporved the socre to  0.5357748826599951 with weight 0.04772727272727273 on feature  4
# Found new weight imporved the socre to  0.5355138834057073 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.5353024520770238 with weight 9.450000000000001 on feature  6
# Found new weight imporved the socre to  0.5357340878185687 with weight 25.3 on feature  7
# Found new weight imporved the socre to  0.5351787515901175 with weight -2.2 on feature  10
# Cell is done 2 16
# adjusting weight on  2 17  with score  0.5481767192005332
# Found new weight imporved the socre to  0.5487316822688272 with weight 360.0 on feature  0
# Found new weight imporved the socre to  0.5484066042580045 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.5483098313386222 with weight 0.1 on feature  2
# Found new weight imporved the socre to  0.5482146383852707 with weight 0.45 on feature  3
# Found new weight imporved the socre to  0.5485946202156614 with weight 0.05 on feature  4
# Found new weight imporved the socre to  0.548998301536513 with weight 2.2 on feature  5
# Found new weight imporved the socre to  0.5486495240352293 with weight 8.549999999999999 on feature  6
# Found new weight imporved the socre to  0.5483149662282222 with weight 24.150000000000002 on feature  7
# Found new weight imporved the socre to  0.5483675000987439 with weight 0.57 on feature  9
# Found new weight imporved the socre to  0.5485100920330173 with weight -2.2 on feature  10
# Cell is done 2 17
# adjusting weight on  2 18  with score  0.5292188815900244
# Found new weight imporved the socre to  0.5292205659423909 with weight 420.0 on feature  0
# Found new weight imporved the socre to  0.5293700522149192 with weight 1.9 on feature  5
# Found new weight imporved the socre to  0.5293005726798004 with weight 9.450000000000001 on feature  6
# Found new weight imporved the socre to  0.5294159508169066 with weight -2.2 on feature  10
# Cell is done 2 18
# Cell is done 2 19
# Elapsed time overall: 10842.761400461197 seconds 2
# adjusting weight on  3 0  with score  0.5368592495328484
# Found new weight imporved the socre to  0.5373758901065567 with weight 440.00000000000006 on feature  0
# Found new weight imporved the socre to  0.5374006363314949 with weight 950.0 on feature  1
# Found new weight imporved the socre to  0.5371652946820833 with weight 0.09047619047619046 on feature  2
# Found new weight imporved the socre to  0.5370208575324442 with weight 0.04090909090909091 on feature  4
# Found new weight imporved the socre to  0.5372627645068395 with weight 1.9 on feature  5
# Found new weight imporved the socre to  0.5369905560325201 with weight 8.1 on feature  6
# Found new weight imporved the socre to  0.5373976061815025 with weight 25.3 on feature  7
# Found new weight imporved the socre to  0.5372304429069202 with weight 0.54 on feature  9
# Found new weight imporved the socre to  0.5371703449320706 with weight -2.1 on feature  10
# Cell is done 3 0
# adjusting weight on  3 1  with score  0.5448128415927947
# Found new weight imporved the socre to  0.545199099802504 with weight 440.00000000000006 on feature  0
# Found new weight imporved the socre to  0.5449552197675984 with weight 950.0 on feature  1
# Found new weight imporved the socre to  0.5451788912873706 with weight 0.1 on feature  2
# Found new weight imporved the socre to  0.5453676571900941 with weight 0.45 on feature  3
# Found new weight imporved the socre to  0.5451678684609342 with weight 0.04090909090909091 on feature  4
# Found new weight imporved the socre to  0.5449272034170726 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.5452225233086814 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5453965921094898 with weight 20.7 on feature  7
# Found new weight imporved the socre to  0.5449813989803849 with weight 0.57 on feature  9
# Found new weight imporved the socre to  0.5450939236669232 with weight -2.1 on feature  10
# Cell is done 3 1
# Cell is done 3 2
# adjusting weight on  3 3  with score  0.5130659902916825
# Found new weight imporved the socre to  0.5131232780863211 with weight 380.0 on feature  0
# Found new weight imporved the socre to  0.5133419337910484 with weight 950.0 on feature  1
# Found new weight imporved the socre to  0.5130900424192025 with weight 0.1 on feature  2
# Found new weight imporved the socre to  0.5137508199588885 with weight 2.1 on feature  5
# Found new weight imporved the socre to  0.5134180259762936 with weight 8.549999999999999 on feature  6
# Found new weight imporved the socre to  0.5131009752044389 with weight 0.66 on feature  9
# Found new weight imporved the socre to  0.5130966020903444 with weight -2.2 on feature  10
# Cell is done 3 3
# adjusting weight on  3 4  with score  0.5217533205172977
# Found new weight imporved the socre to  0.5219997378538934 with weight 360.0 on feature  0
# Found new weight imporved the socre to  0.5219429395316284 with weight 950.0 on feature  1
# Found new weight imporved the socre to  0.5221701328206881 with weight 0.55 on feature  3
# Found new weight imporved the socre to  0.5220381859489649 with weight 1.9 on feature  5
# Found new weight imporved the socre to  0.5218297797972697 with weight 9.450000000000001 on feature  6
# Found new weight imporved the socre to  0.5221578993358926 with weight 25.3 on feature  7
# Found new weight imporved the socre to  0.5221544040545225 with weight 0.63 on feature  9
# Found new weight imporved the socre to  0.5217825934987728 with weight -1.9 on feature  10
# Cell is done 3 4
# Cell is done 3 5
# adjusting weight on  3 6  with score  0.5321238523515045
# Found new weight imporved the socre to  0.5322418961963611 with weight 420.0 on feature  0
# Found new weight imporved the socre to  0.5324611204796662 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.5321477421772494 with weight 0.55 on feature  3
# Found new weight imporved the socre to  0.5327121978639646 with weight 0.04090909090909091 on feature  4
# Found new weight imporved the socre to  0.5323753981637585 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5327356192617535 with weight 25.3 on feature  7
# Found new weight imporved the socre to  0.5324437886453025 with weight 0.63 on feature  9
# Found new weight imporved the socre to  0.5321243207794604 with weight -2.1 on feature  10
# Cell is done 3 6
# adjusting weight on  3 7  with score  0.5462850335715794
# Found new weight imporved the socre to  0.5464232185401737 with weight 380.0 on feature  0
# Found new weight imporved the socre to  0.5464626380766693 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.5465436430582591 with weight 0.10476190476190476 on feature  2
# Found new weight imporved the socre to  0.5463656053714495 with weight 0.525 on feature  3
# Found new weight imporved the socre to  0.546464803985268 with weight 0.04772727272727273 on feature  4
# Found new weight imporved the socre to  0.5465341130604251 with weight 2.1 on feature  5
# Found new weight imporved the socre to  0.5468988520684388 with weight 9.450000000000001 on feature  6
# Found new weight imporved the socre to  0.5467788607320732 with weight 20.7 on feature  7
# Found new weight imporved the socre to  0.5464596058046312 with weight 0.63 on feature  9
# Found new weight imporved the socre to  0.546605154862461 with weight -2.2 on feature  10
# Cell is done 3 7
# adjusting weight on  3 8  with score  0.5219294615142342
# Found new weight imporved the socre to  0.5219299113770262 with weight 420.0 on feature  0
# Found new weight imporved the socre to  0.5222353682126913 with weight 950.0 on feature  1
# Found new weight imporved the socre to  0.5223577308920742 with weight 0.09047619047619046 on feature  2
# Found new weight imporved the socre to  0.5224238607224757 with weight 0.45 on feature  3
# Found new weight imporved the socre to  0.5221148049844759 with weight 0.04772727272727273 on feature  4
# Found new weight imporved the socre to  0.5222236717801033 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.5228390840793521 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5219447568491571 with weight 24.150000000000002 on feature  7
# Found new weight imporved the socre to  0.5219735480678355 with weight -2.1 on feature  10
# Cell is done 3 8
# adjusting weight on  3 9  with score  0.5207792207792171
# Found new weight imporved the socre to  0.5208593322386388 with weight 360.0 on feature  0
# Found new weight imporved the socre to  0.5208374384236416 with weight -1.9 on feature  10
# Cell is done 3 9
# Cell is done 3 10
# adjusting weight on  3 11  with score  0.5400410574804694
# Found new weight imporved the socre to  0.5406073502904033 with weight 380.0 on feature  0
# Found new weight imporved the socre to  0.5402353294612424 with weight 1050.0 on feature  1
# Found new weight imporved the socre to  0.540355497696772 with weight 0.09047619047619046 on feature  2
# Found new weight imporved the socre to  0.5402919086721377 with weight 0.475 on feature  3
# Found new weight imporved the socre to  0.5407200080112124 with weight 0.04090909090909091 on feature  4
# Found new weight imporved the socre to  0.5403259563388711 with weight 1.9 on feature  5
# Found new weight imporved the socre to  0.5407180052072869 with weight 9.450000000000001 on feature  6
# Found new weight imporved the socre to  0.5402753855397523 with weight 24.150000000000002 on feature  7
# Found new weight imporved the socre to  0.5401001401962715 with weight 0.57 on feature  9
# Found new weight imporved the socre to  0.5401882635689932 with weight -1.8 on feature  10
# Cell is done 3 11
# Cell is done 3 12
# adjusting weight on  3 13  with score  0.5322602518566315
# Found new weight imporved the socre to  0.5325443978043228 with weight 420.0 on feature  0
# Found new weight imporved the socre to  0.5327182988145172 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.5325213340098673 with weight 0.09047619047619046 on feature  2
# Found new weight imporved the socre to  0.5325351722865407 with weight 0.475 on feature  3
# Found new weight imporved the socre to  0.5323197564463266 with weight 0.04318181818181818 on feature  4
# Found new weight imporved the socre to  0.5324152405553723 with weight 2.2 on feature  5
# Found new weight imporved the socre to  0.5324609068683941 with weight 9.450000000000001 on feature  6
# Found new weight imporved the socre to  0.5326361917062555 with weight 0.66 on feature  9
# Found new weight imporved the socre to  0.5322699386503029 with weight -2.1 on feature  10
# Cell is done 3 13
# adjusting weight on  3 14  with score  0.531239961004592
# Found new weight imporved the socre to  0.5312724571746863 with weight 420.0 on feature  0
# Found new weight imporved the socre to  0.5317780047351522 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.531623415811704 with weight 0.08571428571428572 on feature  2
# Found new weight imporved the socre to  0.5312845271807213 with weight 0.45 on feature  3
# Found new weight imporved the socre to  0.5313857295390148 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.5318239636042855 with weight 25.3 on feature  7
# Found new weight imporved the socre to  0.5315389257694589 with weight 0.66 on feature  9
# Cell is done 3 14
# Cell is done 3 15
# Cell is done 3 16
# adjusting weight on  3 17  with score  0.5460020799930629
# Found new weight imporved the socre to  0.5461342462191756 with weight 420.0 on feature  0
# Found new weight imporved the socre to  0.5464479785067347 with weight 1100.0 on feature  1
# Found new weight imporved the socre to  0.5468041773194052 with weight 0.09047619047619046 on feature  2
# Found new weight imporved the socre to  0.5463188456038442 with weight 0.475 on feature  3
# Found new weight imporved the socre to  0.5464562118126236 with weight 0.04318181818181818 on feature  4
# Found new weight imporved the socre to  0.5466815443948483 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.5469987433375185 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5463478788404001 with weight 20.7 on feature  7
# Found new weight imporved the socre to  0.546600944663514 with weight 0.66 on feature  9
# Found new weight imporved the socre to  0.5461927460241763 with weight -2.2 on feature  10
# Cell is done 3 17
# adjusting weight on  3 18  with score  0.5352923076923038
# Found new weight imporved the socre to  0.5354006888633716 with weight 900.0 on feature  1
# Cell is done 3 18
# adjusting weight on  3 19  with score  0.521542783234304
# Found new weight imporved the socre to  0.5220346792773096 with weight 360.0 on feature  0
# Found new weight imporved the socre to  0.521821268339999 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.5221304716866705 with weight 0.08571428571428572 on feature  2
# Found new weight imporved the socre to  0.5220326583404032 with weight 0.45 on feature  3
# Found new weight imporved the socre to  0.5220177034072961 with weight 0.04090909090909091 on feature  4
# Found new weight imporved the socre to  0.5220164908451523 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.5220759063901991 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5223357988763556 with weight 25.3 on feature  7
# Found new weight imporved the socre to  0.5219392910553299 with weight 0.63 on feature  9
# Found new weight imporved the socre to  0.5219708176710689 with weight -1.8 on feature  10
# Cell is done 3 19
# Elapsed time overall: 11040.9856402874 seconds 3
# Cell is done 4 0
# Cell is done 4 1
# adjusting weight on  4 2  with score  0.5302246222262521
# Found new weight imporved the socre to  0.5306457321776974 with weight 440.00000000000006 on feature  0
# Found new weight imporved the socre to  0.5306180514589062 with weight 1050.0 on feature  1
# Found new weight imporved the socre to  0.5312302037482378 with weight 0.08571428571428572 on feature  2
# Found new weight imporved the socre to  0.5308367745155836 with weight 0.55 on feature  3
# Found new weight imporved the socre to  0.5310128420383863 with weight 0.04772727272727273 on feature  4
# Found new weight imporved the socre to  0.5306861188001959 with weight 2.2 on feature  5
# Found new weight imporved the socre to  0.5311231111312754 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5309978672233024 with weight 25.3 on feature  7
# Found new weight imporved the socre to  0.5307560012705866 with weight 0.66 on feature  9
# Found new weight imporved the socre to  0.530298134954845 with weight -1.8 on feature  10
# Cell is done 4 2
# adjusting weight on  4 3  with score  0.5450527945938298
# Found new weight imporved the socre to  0.5451949880332216 with weight 420.0 on feature  0
# Found new weight imporved the socre to  0.5450800131399839 with weight 1050.0 on feature  1
# Found new weight imporved the socre to  0.5450884602749972 with weight 0.45 on feature  3
# Found new weight imporved the socre to  0.5455844948143939 with weight 0.05 on feature  4
# Found new weight imporved the socre to  0.5452278380027181 with weight 8.549999999999999 on feature  6
# Found new weight imporved the socre to  0.5455319348631996 with weight 20.7 on feature  7
# Found new weight imporved the socre to  0.5453118400675733 with weight 0.57 on feature  9
# Found new weight imporved the socre to  0.5451058238303026 with weight -1.9 on feature  10
# Cell is done 4 3
# adjusting weight on  4 4  with score  0.5262142388143665
# Found new weight imporved the socre to  0.5270298283463053 with weight 440.00000000000006 on feature  0
# Found new weight imporved the socre to  0.5266686989963381 with weight 950.0 on feature  1
# Found new weight imporved the socre to  0.5265448832192066 with weight 0.08571428571428572 on feature  2
# Found new weight imporved the socre to  0.5266654160022475 with weight 0.05 on feature  4
# Found new weight imporved the socre to  0.5265401932276484 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.5267765688021725 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5265350342369346 with weight 24.150000000000002 on feature  7
# Found new weight imporved the socre to  0.5267451458587337 with weight 0.54 on feature  9
# Found new weight imporved the socre to  0.526451552387202 with weight -2.1 on feature  10
# Cell is done 4 4
# adjusting weight on  4 5  with score  0.533791392264165
# Found new weight imporved the socre to  0.53384055282441 with weight 0.04090909090909091 on feature  4
# Found new weight imporved the socre to  0.5338674519988835 with weight 1.9 on feature  5
# Found new weight imporved the socre to  0.5342454317781248 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5338002040626996 with weight 21.849999999999998 on feature  7
# Found new weight imporved the socre to  0.5340914571932069 with weight 0.57 on feature  9
# Cell is done 4 5
# adjusting weight on  4 6  with score  0.5419290731540133
# Found new weight imporved the socre to  0.5424139112557779 with weight 420.0 on feature  0
# Found new weight imporved the socre to  0.5425158471817674 with weight 1050.0 on feature  1
# Found new weight imporved the socre to  0.5420215864313818 with weight 0.10476190476190476 on feature  2
# Found new weight imporved the socre to  0.5427342813088876 with weight 0.55 on feature  3
# Found new weight imporved the socre to  0.5421642110673249 with weight 0.04318181818181818 on feature  4
# Found new weight imporved the socre to  0.5423655131060435 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.5426494774712997 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5429090286105835 with weight 20.7 on feature  7
# Found new weight imporved the socre to  0.5420819770429974 with weight 0.54 on feature  9
# Found new weight imporved the socre to  0.5423368168579709 with weight -2.1 on feature  10
# Cell is done 4 6
# Cell is done 4 7
# Cell is done 4 8
# adjusting weight on  4 9  with score  0.5344901509096857
# Found new weight imporved the socre to  0.5346876028395432 with weight -2.2 on feature  10
# Cell is done 4 9
# adjusting weight on  4 10  with score  0.5123252220934688
# Found new weight imporved the socre to  0.5126467748165279 with weight 420.0 on feature  0
# Found new weight imporved the socre to  0.5126366357667017 with weight 1050.0 on feature  1
# Found new weight imporved the socre to  0.512329567400537 with weight 0.09047619047619046 on feature  2
# Found new weight imporved the socre to  0.5128539011201199 with weight 0.45 on feature  3
# Found new weight imporved the socre to  0.5130127462340635 with weight 0.04090909090909091 on feature  4
# Found new weight imporved the socre to  0.5127964465044382 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.51242806102742 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5131822132097298 with weight 25.3 on feature  7
# Found new weight imporved the socre to  0.5128046543066784 with weight 0.66 on feature  9
# Found new weight imporved the socre to  0.5123792970258751 with weight -1.8 on feature  10
# Cell is done 4 10
# adjusting weight on  4 11  with score  0.5453378406404209
# Found new weight imporved the socre to  0.5454266041727116 with weight 380.0 on feature  0
# Found new weight imporved the socre to  0.5455871251399853 with weight 950.0 on feature  1
# Found new weight imporved the socre to  0.5458791322742506 with weight 0.08571428571428572 on feature  2
# Found new weight imporved the socre to  0.5457397652328967 with weight 0.45 on feature  3
# Found new weight imporved the socre to  0.5454855033389981 with weight 0.04772727272727273 on feature  4
# Found new weight imporved the socre to  0.5456771330208596 with weight 2.2 on feature  5
# Found new weight imporved the socre to  0.5457679704674564 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5456132564602392 with weight 21.849999999999998 on feature  7
# Found new weight imporved the socre to  0.5455174416193084 with weight 0.54 on feature  9
# Found new weight imporved the socre to  0.5455311294537271 with weight -2.2 on feature  10
# Cell is done 4 11
# Cell is done 4 12
# adjusting weight on  4 13  with score  0.5380699381761943
# Found new weight imporved the socre to  0.5381665378670751 with weight 420.0 on feature  0
# Found new weight imporved the socre to  0.5384824188562561 with weight 0.475 on feature  3
# Found new weight imporved the socre to  0.5385746715610474 with weight 0.04318181818181818 on feature  4
# Found new weight imporved the socre to  0.5381839258114338 with weight 8.549999999999999 on feature  6
# Found new weight imporved the socre to  0.5381254829984509 with weight 25.3 on feature  7
# Found new weight imporved the socre to  0.5382974304482191 with weight -2.1 on feature  10
# Cell is done 4 13
# adjusting weight on  4 14  with score  0.5389514581285364
# Found new weight imporved the socre to  0.5399372747273286 with weight 360.0 on feature  0
# Found new weight imporved the socre to  0.5400449375087731 with weight 950.0 on feature  1
# Found new weight imporved the socre to  0.5399185507653383 with weight 0.1 on feature  2
# Found new weight imporved the socre to  0.5401741328465066 with weight 0.55 on feature  3
# Found new weight imporved the socre to  0.5396620324860704 with weight 0.04772727272727273 on feature  4
# Found new weight imporved the socre to  0.5399031034966962 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.5401263867434312 with weight 9.450000000000001 on feature  6
# Found new weight imporved the socre to  0.5397795253475599 with weight 21.849999999999998 on feature  7
# Found new weight imporved the socre to  0.5397519075036242 with weight 0.54 on feature  9
# Found new weight imporved the socre to  0.5393011281187062 with weight -1.9 on feature  10
# Cell is done 4 14
# adjusting weight on  4 15  with score  0.5427240740740705
# Found new weight imporved the socre to  0.5429550925925892 with weight 0.45 on feature  3
# Found new weight imporved the socre to  0.5430120370370336 with weight 0.04318181818181818 on feature  4
# Found new weight imporved the socre to  0.5428074074074039 with weight 1.9 on feature  5
# Cell is done 4 15
# Cell is done 4 16
# adjusting weight on  4 17  with score  0.5437565196296404
# Found new weight imporved the socre to  0.5444944001940687 with weight 440.00000000000006 on feature  0
# Found new weight imporved the socre to  0.5438402134799619 with weight 1100.0 on feature  1
# Found new weight imporved the socre to  0.5442558525047467 with weight 0.09047619047619046 on feature  2
# Found new weight imporved the socre to  0.5440925079852788 with weight 0.475 on feature  3
# Found new weight imporved the socre to  0.5441470909311406 with weight 0.04090909090909091 on feature  4
# Found new weight imporved the socre to  0.5440492459467067 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.5445780940443901 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5439024784700561 with weight 25.3 on feature  7
# Found new weight imporved the socre to  0.5440063882262524 with weight 0.66 on feature  9
# Found new weight imporved the socre to  0.543912182104876 with weight -1.8 on feature  10
# Cell is done 4 17
# adjusting weight on  4 18  with score  0.5258497713308966
# Found new weight imporved the socre to  0.5259735760151486 with weight 0.525 on feature  3
# Found new weight imporved the socre to  0.5261736037326152 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.5260673534438917 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5261181687993681 with weight 24.150000000000002 on feature  7
# Found new weight imporved the socre to  0.526000831523995 with weight -2.2 on feature  10
# Cell is done 4 18
# adjusting weight on  4 19  with score  0.5392231170061541
# Found new weight imporved the socre to  0.5396679729555103 with weight 440.00000000000006 on feature  0
# Found new weight imporved the socre to  0.539304508849744 with weight 950.0 on feature  1
# Found new weight imporved the socre to  0.5403333189785067 with weight 0.09047619047619046 on feature  2
# Found new weight imporved the socre to  0.5397665905861032 with weight 0.475 on feature  3
# Found new weight imporved the socre to  0.5393660910382801 with weight 0.04772727272727273 on feature  4
# Found new weight imporved the socre to  0.5396744326256364 with weight 1.9 on feature  5
# Found new weight imporved the socre to  0.5403001593385257 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5399935403298698 with weight 24.150000000000002 on feature  7
# Found new weight imporved the socre to  0.5400512467163302 with weight 0.66 on feature  9
# Found new weight imporved the socre to  0.5396559149046082 with weight -2.2 on feature  10
# Cell is done 4 19
# Elapsed time overall: 11360.408630371094 seconds 4
# adjusting weight on  5 0  with score  0.49322224259649367
# Found new weight imporved the socre to  0.49334509947739585 with weight 440.00000000000006 on feature  0
# Found new weight imporved the socre to  0.49356697533693555 with weight 1050.0 on feature  1
# Found new weight imporved the socre to  0.49449206931328105 with weight 0.08571428571428572 on feature  2
# Found new weight imporved the socre to  0.49356651691573816 with weight 0.525 on feature  3
# Found new weight imporved the socre to  0.4932593747134825 with weight 0.04090909090909091 on feature  4
# Found new weight imporved the socre to  0.4934670395159032 with weight 2.1 on feature  5
# Found new weight imporved the socre to  0.4939259191344968 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.49367195379113926 with weight 24.150000000000002 on feature  7
# Found new weight imporved the socre to  0.49349821215732614 with weight 0.63 on feature  9
# Found new weight imporved the socre to  0.49355689007059284 with weight -1.8 on feature  10
# Cell is done 5 0
# adjusting weight on  5 1  with score  0.5161111361079824
# Found new weight imporved the socre to  0.5161714285714246 with weight 360.0 on feature  0
# Found new weight imporved the socre to  0.5162830146231681 with weight 950.0 on feature  1
# Found new weight imporved the socre to  0.5161660292463403 with weight 0.1 on feature  2
# Found new weight imporved the socre to  0.5161498312710872 with weight 0.475 on feature  3
# Found new weight imporved the socre to  0.5161948256467902 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.516339257592797 with weight 25.3 on feature  7
# Found new weight imporved the socre to  0.5164368953880725 with weight 0.66 on feature  9
# Found new weight imporved the socre to  0.5161777277840229 with weight -2.2 on feature  10
# Cell is done 5 1
# adjusting weight on  5 2  with score  0.5376998027613371
# Found new weight imporved the socre to  0.5377179487179445 with weight 360.0 on feature  0
# Found new weight imporved the socre to  0.5382753451676486 with weight 0.08571428571428572 on feature  2
# Found new weight imporved the socre to  0.5379013806706073 with weight 0.55 on feature  3
# Found new weight imporved the socre to  0.5377155818540393 with weight 0.04318181818181818 on feature  4
# Found new weight imporved the socre to  0.5378658777120275 with weight 1.9 on feature  5
# Found new weight imporved the socre to  0.5382524654832307 with weight 9.9 on feature  6
# ...
# Cell is done 7 17
# adjusting weight on  7 18  with score  0.5357149278329887
# Found new weight imporved the socre to  0.5369040603306163 with weight 380.0 on feature  0
# Found new weight imporved the socre to  0.5360180792089064 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.536224342006689 with weight 0.1 on feature  2
# Found new weight imporved the socre to  0.5362363282225406 with weight 0.55 on feature  3
# Found new weight imporved the socre to  0.5363946461569161 with weight 0.05 on feature  4
# Found new weight imporved the socre to  0.5362932627478366 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.5361988712980039 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5365389801727979 with weight 20.7 on feature  7
# Found new weight imporved the socre to  0.5363267242670896 with weight 0.54 on feature  9
# Cell is done 7 18
# Cell is done 7 19
# Elapsed time overall: 11740.545201063156 seconds 7
# adjusting weight on  8 0  with score  0.5331202797202759
# Found new weight imporved the socre to  0.5332186480186443 with weight 420.0 on feature  0
# Found new weight imporved the socre to  0.5334587412587374 with weight 950.0 on feature  1
# Found new weight imporved the socre to  0.5331268065268027 with weight 0.1 on feature  2
# Found new weight imporved the socre to  0.5336013986013948 with weight 0.525 on feature  3
# Found new weight imporved the socre to  0.5332797202797165 with weight 0.05 on feature  4
# Found new weight imporved the socre to  0.5334377622377585 with weight 2.2 on feature  5
# Found new weight imporved the socre to  0.5336615384615346 with weight 8.549999999999999 on feature  6
# Found new weight imporved the socre to  0.5333431235431197 with weight 21.849999999999998 on feature  7
# Found new weight imporved the socre to  0.5336372960372923 with weight 0.66 on feature  9
# Found new weight imporved the socre to  0.5334773892773855 with weight -2.2 on feature  10
# Cell is done 8 0
# Cell is done 8 1
# Cell is done 8 2
# adjusting weight on  8 3  with score  0.5320133932505026
# Found new weight imporved the socre to  0.5320459952418674 with weight 420.0 on feature  0
# Found new weight imporved the socre to  0.5321195700061636 with weight 950.0 on feature  1
# Found new weight imporved the socre to  0.5320477575116709 with weight 0.525 on feature  3
# Found new weight imporved the socre to  0.5321711163979164 with weight 0.04318181818181818 on feature  4
# Found new weight imporved the socre to  0.5323574764296373 with weight 1.9 on feature  5
# Found new weight imporved the socre to  0.5323178253590582 with weight 20.7 on feature  7
# Found new weight imporved the socre to  0.5322504185390743 with weight 0.54 on feature  9
# Found new weight imporved the socre to  0.5322772931535777 with weight -2.1 on feature  10
# Cell is done 8 3
# Cell is done 8 4
# Cell is done 8 5
# adjusting weight on  8 6  with score  0.5299272364814315
# Found new weight imporved the socre to  0.5305422377273822 with weight 440.00000000000006 on feature  0
# Found new weight imporved the socre to  0.5304899077996472 with weight 1100.0 on feature  1
# Found new weight imporved the socre to  0.5306045352603999 with weight 0.09047619047619046 on feature  2
# Found new weight imporved the socre to  0.5305596810366272 with weight 0.45 on feature  3
# Found new weight imporved the socre to  0.5300971841515038 with weight 0.05 on feature  4
# Found new weight imporved the socre to  0.5302855718913493 with weight 1.9 on feature  5
# Found new weight imporved the socre to  0.5305836032893059 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5308437577871877 with weight 21.849999999999998 on feature  7
# Found new weight imporved the socre to  0.5304634936456478 with weight 0.57 on feature  9
# Found new weight imporved the socre to  0.530087216546221 with weight -1.8 on feature  10
# Cell is done 8 6
# Cell is done 8 7
# adjusting weight on  8 8  with score  0.5269492605233179
# Found new weight imporved the socre to  0.5270962457337844 with weight 440.00000000000006 on feature  0
# Found new weight imporved the socre to  0.5275968145619984 with weight 950.0 on feature  1
# Found new weight imporved the socre to  0.5274006825938525 with weight 0.1 on feature  2
# Found new weight imporved the socre to  0.5277406143344671 with weight 0.04318181818181818 on feature  4
# Found new weight imporved the socre to  0.5274211604095523 with weight 2.1 on feature  5
# Found new weight imporved the socre to  0.5271877133105762 with weight 8.549999999999999 on feature  6
# Found new weight imporved the socre to  0.5276409556313953 with weight 25.3 on feature  7
# Found new weight imporved the socre to  0.5272600682593817 with weight 0.63 on feature  9
# Cell is done 8 8
# adjusting weight on  8 9  with score  0.5311980768397763
# Found new weight imporved the socre to  0.5315831420279775 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.531218867761074 with weight 0.1 on feature  2
# Found new weight imporved the socre to  0.5316056655260498 with weight 0.05 on feature  4
# Found new weight imporved the socre to  0.5312340278078536 with weight 2.1 on feature  5
# Found new weight imporved the socre to  0.5315805431628152 with weight 8.549999999999999 on feature  6
# Found new weight imporved the socre to  0.5313319183956301 with weight 21.849999999999998 on feature  7
# Found new weight imporved the socre to  0.5313955905921045 with weight -2.2 on feature  10
# Cell is done 8 9
# Cell is done 8 10
# Cell is done 8 11
# Cell is done 8 12
# adjusting weight on  8 13  with score  0.5467589534075066
# Found new weight imporved the socre to  0.5471983657858097 with weight 360.0 on feature  0
# Found new weight imporved the socre to  0.5475691063977708 with weight 0.09047619047619046 on feature  2
# Found new weight imporved the socre to  0.5467772079276735 with weight 0.475 on feature  3
# Found new weight imporved the socre to  0.5475695410292033 with weight 0.05 on feature  4
# Found new weight imporved the socre to  0.5471440368567416 with weight 1.9 on feature  5
# Found new weight imporved the socre to  0.5469988699582714 with weight 9.450000000000001 on feature  6
# Found new weight imporved the socre to  0.5473317976356011 with weight 24.150000000000002 on feature  7
# Found new weight imporved the socre to  0.5473383171070894 with weight 0.54 on feature  9
# Found new weight imporved the socre to  0.5468689151599406 with weight -2.1 on feature  10
# Cell is done 8 13
# adjusting weight on  8 14  with score  0.5328802676795042
# Found new weight imporved the socre to  0.5335074154458274 with weight 420.0 on feature  0
# Found new weight imporved the socre to  0.533040332790736 with weight 950.0 on feature  1
# Found new weight imporved the socre to  0.533093235666482 with weight 0.09047619047619046 on feature  2
# Found new weight imporved the socre to  0.5331438777355723 with weight 0.55 on feature  3
# Found new weight imporved the socre to  0.5337018448182274 with weight 0.04318181818181818 on feature  4
# Found new weight imporved the socre to  0.5331334780249555 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.5331976849339807 with weight 20.7 on feature  7
# Found new weight imporved the socre to  0.5331936154820002 with weight -2.2 on feature  10
# Cell is done 8 14
# Cell is done 8 15
# adjusting weight on  8 16  with score  0.5455537023219027
# Found new weight imporved the socre to  0.545696791467318 with weight 360.0 on feature  0
# Found new weight imporved the socre to  0.545751218013427 with weight 0.525 on feature  3
# Found new weight imporved the socre to  0.5456687003467456 with weight 0.04772727272727273 on feature  4
# Found new weight imporved the socre to  0.5459386384584957 with weight 9.450000000000001 on feature  6
# Found new weight imporved the socre to  0.5458183733485454 with weight 24.150000000000002 on feature  7
# Found new weight imporved the socre to  0.5457569240222934 with weight 0.57 on feature  9
# Cell is done 8 16
# adjusting weight on  8 17  with score  0.5355836196489884
# Found new weight imporved the socre to  0.5356704429380589 with weight 380.0 on feature  0
# Found new weight imporved the socre to  0.5356941220168964 with weight 950.0 on feature  1
# Found new weight imporved the socre to  0.5357725879840243 with weight 0.09047619047619046 on feature  2
# Found new weight imporved the socre to  0.5359810567369261 with weight 0.475 on feature  3
# Found new weight imporved the socre to  0.5357247655306859 with weight 1.9 on feature  5
# Found new weight imporved the socre to  0.5362234190732618 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5362568483610323 with weight 20.7 on feature  7
# Found new weight imporved the socre to  0.5363585291113341 with weight 0.54 on feature  9
# Cell is done 8 17
# adjusting weight on  8 18  with score  0.5229586158522288
# Found new weight imporved the socre to  0.5232620996025209 with weight 380.0 on feature  0
# Found new weight imporved the socre to  0.5234828150572791 with weight 0.09047619047619046 on feature  2
# Found new weight imporved the socre to  0.5229833995791402 with weight 0.55 on feature  3
# Found new weight imporved the socre to  0.523160626607431 with weight 1.9 on feature  5
# Found new weight imporved the socre to  0.5231592237549643 with weight 8.1 on feature  6
# Found new weight imporved the socre to  0.5233733925648778 with weight 24.150000000000002 on feature  7
# Found new weight imporved the socre to  0.522966097732051 with weight 0.54 on feature  9
# Cell is done 8 18
# adjusting weight on  8 19  with score  0.5311162339238014
# Found new weight imporved the socre to  0.5312901399336695 with weight 420.0 on feature  0
# Found new weight imporved the socre to  0.5319137749737083 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.5313625333656843 with weight 0.09047619047619046 on feature  2
# Found new weight imporved the socre to  0.5312088489848706 with weight 0.475 on feature  3
# Found new weight imporved the socre to  0.5315332039149038 with weight 0.04090909090909091 on feature  4
# Found new weight imporved the socre to  0.5313698131521439 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.5316674755318251 with weight 9.450000000000001 on feature  6
# Found new weight imporved the socre to  0.5313358408153325 with weight 21.849999999999998 on feature  7
# Found new weight imporved the socre to  0.5311364555528557 with weight 0.63 on feature  9
# Found new weight imporved the socre to  0.5312646606810609 with weight -1.9 on feature  10
# Cell is done 8 19
# Elapsed time overall: 8647.784123182297 seconds 8
# Cell is done 9 0
# Cell is done 9 1
# Cell is done 9 2
# Cell is done 9 3
# Cell is done 9 4
# Cell is done 9 5
# Cell is done 9 6
# Cell is done 9 7
# Cell is done 9 8
# adjusting weight on  9 9  with score  0.5358392952960076
# Found new weight imporved the socre to  0.5361751028438523 with weight 440.00000000000006 on feature  0
# Found new weight imporved the socre to  0.535942139152205 with weight 900.0 on feature  1
# Found new weight imporved the socre to  0.5365784296190267 with weight 0.08571428571428572 on feature  2
# Found new weight imporved the socre to  0.5361384367733818 with weight 0.45 on feature  3
# Found new weight imporved the socre to  0.5361080307637235 with weight 0.04772727272727273 on feature  4
# Found new weight imporved the socre to  0.5360624217492359 with weight 1.8 on feature  5
# Found new weight imporved the socre to  0.5361979073510961 with weight 9.9 on feature  6
# Found new weight imporved the socre to  0.5360145769987439 with weight 20.7 on feature  7
# Found new weight imporved the socre to  0.5359855124306883 with weight 0.54 on feature  9
# Found new weight imporved the socre to  0.536125469504557 with weight -2.2 on feature  10
# Cell is done 9 9
# Cell is done 9 10
# Cell is done 9 11
# Cell is done 9 12
# Cell is done 9 13
# Cell is done 9 14
# Cell is done 9 15
# Cell is done 9 16
# Cell is done 9 17
# Cell is done 9 18
# Cell is done 9 19
# Elapsed time overall: 1021.6663327217102 seconds 9
# Final: 0.5483083948027339
# [[400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2], [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2], [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2], [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2], [360.0, 1000, 0.09523809523809523, 0.5, 0.05, 2, 9, 20.7, 4.5, 0.57, -2.1], [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2], [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2], [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2], [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2], [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2], [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2], [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2], [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2], [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2], [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2], [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2], [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2], [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2], [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2], [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2], [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2], [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],
],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],\
 [360.0, 1000, 0.09047619047619046, 0.475, 0.05, 1.9, 9.450000000000001, 24.150000000000002, 4.5, 0.54, -2.1],\
 [420.0, 950.0, 0.09047619047619046, 0.55, 0.04318181818181818, 1.8, 9, 20.7, 4.5, 0.6, -2.2],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],\
 [360.0, 1000, 0.09523809523809523, 0.525, 0.04772727272727273, 2, 9.450000000000001, 24.150000000000002, 4.5, 0.57, -2],\
 [380.0, 950.0, 0.09047619047619046, 0.475, 0.045454545454545456, 1.9, 9.9, 20.7, 4.5, 0.54, -2],\
 [380.0, 1000, 0.09047619047619046, 0.55, 0.045454545454545456, 1.9, 8.1, 24.150000000000002, 4.5, 0.54, -2],\
 [420.0, 900.0, 0.09047619047619046, 0.475, 0.04090909090909091, 1.8, 9.450000000000001, 21.849999999999998, 4.5, 0.63, -1.9],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],\
 [440.00000000000006, 900.0, 0.08571428571428572, 0.45, 0.04772727272727273, 1.8, 9.9, 20.7, 4.5, 0.54, -2.2],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2],\
 [400, 1000, 0.09523809523809523, 0.5, 0.045454545454545456, 2, 9, 23, 4.5, 0.6, -2]]

# %%
def run_test():
    
    # Run test
    df = pd.read_csv('../../train.csv',
                           usecols=['row_id','x','y','accuracy','time','place_id'])
    df_test = pd.read_csv('../../test.csv',
                           usecols=['row_id','x','y','accuracy','time'])
    
    n_cell_x = 10
    n_cell_y = 20
    x_length = 10 / n_cell_x
    y_length = 10 / n_cell_y
    counter = 0
    total_result = pd.DataFrame()
    global fw
    
    for x_index in range(0, n_cell_x):
        start_time = time.time()
        for y_index in range(0, n_cell_y):
            min_x = x_index * x_length
            max_x = (x_index + 1) * x_length
            min_y = y_index * y_length
            max_y = (y_index + 1) * y_length
            
            # include the edge
            if(y_index + 1 == n_cell_y):
                max_y += 0.1
            if(x_index + 1 == n_cell_x):
                max_x += 0.1

            df_train_cell = df[(df.x >= min_x - 0.1) & \
                               (df.x < max_x + 0.1) & \
                               (df.y >= min_y - 0.1) & \
                               (df.y < max_y + 0.1)].copy()
            
            df_test_cell = df_test[(df_test.x >= min_x) & \
                                   (df_test.x < max_x) & \
                                   (df_test.y >= min_y) & \
                                   (df_test.y < max_y)].copy()
            fw = fw_final[counter]
            prediction_result = run_prediction(df_train_cell, df_test_cell)
            total_result = total_result.append(prediction_result)
            counter += 1
        print("Elapsed time overall: %s seconds" % (time.time() - start_time), x_index, flush = True)
            
    
    total_result.sort_index(inplace=True)
    total_result['place_id'] = total_result.p1.astype(str) + " " + \
                               total_result.p2.astype(str) + " " + \
                               total_result.p3.astype(str)
    total_result[['row_id', 'place_id']].to_csv('Baseline620.csv', index=False)

# %%
run_test()
# Out:
# Elapsed time overall: 663.994193315506 seconds 0
# Elapsed time overall: 740.8766412734985 seconds 1
# Elapsed time overall: 745.5363931655884 seconds 2
# Elapsed time overall: 704.3780963420868 seconds 3
# Elapsed time overall: 690.7077469825745 seconds 4
# Elapsed time overall: 720.6914947032928 seconds 5
# Elapsed time overall: 692.8503804206848 seconds 6
# Elapsed time overall: 722.5725965499878 seconds 7
# Elapsed time overall: 689.5900194644928 seconds 8
# Elapsed time overall: 624.4675269126892 seconds 9

# %%
0.58065
