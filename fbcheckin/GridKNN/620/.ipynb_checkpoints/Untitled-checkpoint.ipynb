# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import time

# %%
df = pd.read_csv('../../train.csv',
                       usecols=['row_id','x','y','accuracy','time','place_id'])

df_train = df[(df.time <= 786239 * 0.875)]
df_validate = df[(df.time > 786239 * 0.875)]

# %%
df = None

# %%
average_x = df_train.groupby(['place_id'])['x'].mean()

# %%
average_y = df_train.groupby(['place_id'])['y'].mean()

# %%
average_location = pd.DataFrame(average_x.index)

# %%
average_location['x'] = average_x.values
average_location['y'] = average_y.values

# %%
average_location.index = average_location.place_id.values

# %%
average_location.head()
# Out:
#               place_id         x         y
# 1000015801  1000015801  2.683916  5.549939
# 1000017288  1000017288  7.330497  4.346579
# 1000025138  1000025138  0.988281  5.570404
# 1000052096  1000052096  2.858615  5.833298
# 1000063498  1000063498  3.921452  7.551044

# %%
clf = KNeighborsClassifier(n_neighbors=25, weights="distance", metric='manhattan')
clf.fit(average_location[['x', 'y']], average_location[['place_id']])
predictions = clf.predict_proba(df_validate[['x', 'y']])

# %%
df_validate[['x', 'y']]
# Out:
#                x       y
# 3         7.3665  2.5165
# 16        3.2494  3.2096
# 20        5.3298  6.3457
# 23        7.4492  8.9950
# 27        4.3794  7.2107
# 34        3.1667  6.2971
# 35        8.5522  0.5541
# 44        2.0768  4.4422
# 52        1.3307  9.9828
# 56        4.4478  9.7351
# 58        4.5698  4.1206
# 66        0.3093  5.7269
# 74        1.8616  2.8019
# 80        1.6690  5.7207
# 89        5.4847  7.4100
# 90        4.8707  6.2239
# 100       9.7952  7.7306
# 109       0.4995  1.4831
# 117       9.0473  7.5661
# 140       8.2384  3.0428
# 161       6.6964  8.6501
# 168       7.9796  1.1972
# 199       3.2288  3.0644
# 202       5.7595  1.8637
# 208       7.8066  4.0105
# 215       1.6094  5.9324
# 218       8.5792  4.2878
# 221       0.7609  5.2923
# 229       4.6574  4.8631
# 230       2.6284  5.3755
# ...          ...     ...
# 29117807  3.6092  5.4511
# 29117815  8.3892  1.4290
# 29117819  2.6425  8.6041
# 29117832  8.2721  2.1777
# 29117840  5.1536  9.4767
# 29117858  6.1239  4.1254
# 29117867  7.8073  3.2094
# 29117878  1.9810  6.5555
# 29117888  8.2789  4.5922
# 29117895  9.6256  0.9481
# 29117897  4.5834  3.6685
# 29117902  8.8511  9.2440
# 29117905  6.6997  7.9942
# 29117916  3.5942  3.9441
# 29117919  0.4441  5.6229
# 29117935  2.9321  2.6373
# 29117938  8.1063  2.2087
# 29117939  8.7649  8.7089
# 29117944  2.9713  3.9731
# 29117945  6.3396  7.1078
# 29117957  0.8322  3.7894
# 29117959  4.3084  5.4099
# 29117962  3.1113  4.5805
# 29117963  2.0423  8.4759
# 29117965  0.7073  6.2553
# 29117975  8.2064  0.3794
# 29117978  0.0667  5.8000
# 29118008  8.7879  9.7045
# 29118018  2.9993  6.3680
# 29118019  4.0637  8.0061
#
# [4417684 rows x 2 columns]
