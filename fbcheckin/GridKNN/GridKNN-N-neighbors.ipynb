# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import time

# %%
feature_list = ['x','y','hour','weekday','day','month','year']

# %%
def prepare_data(df, n_cell_x, n_cell_y):
    #Creating the grid
    size_x = 10. / n_cell_x
    size_y = 10. / n_cell_y
    eps = 0.00001  
    xs = np.where(df.x.values < eps, 0, df.x.values - eps)
    ys = np.where(df.y.values < eps, 0, df.y.values - eps)
    pos_x = (xs / size_x).astype(np.int)
    pos_y = (ys / size_y).astype(np.int)
    df['grid_x'] = pos_x
    df['grid_y'] = pos_y
    
    #Feature engineering
    fw = [500, 1000, 4, 3, 1./22., 2, 10] #feature weights (black magic here)
    df.x = df.x.values * fw[0]
    df.y = df.y.values * fw[1]
    initial_date = np.datetime64('2014-01-01T01:01', dtype='datetime64[m]') 
    d_times = pd.DatetimeIndex(initial_date + np.timedelta64(int(mn), 'm') 
                               for mn in df.time.values)    
    df['hour'] = (d_times.hour+ d_times.minute/60) * fw[2]
    df['weekday'] = d_times.weekday * fw[3]
    df['day'] = (d_times.dayofyear * fw[4]).astype(int)
    df['month'] = d_times.month * fw[5]
    df['year'] = (d_times.year - 2013) * fw[6]
    
    return df

# %%
def run_prediction(df_train, df_test, n_cell_x, n_cell_y, th):
    total_result = pd.DataFrame()
    for x_grid in range(0, n_cell_x):
        start_time = time.time()
        for y_grid in range(0, n_cell_y):
            total_result = total_result.append(process_one_cell(df_train, df_test, x_grid, y_grid, th))
        print("Elapsed time overall: %s seconds" % (time.time() - start_time), x_grid, flush = True)
    return total_result

# %%
def process_one_cell(df_train, df_test, grid_x, grid_y, th):
    start_time = time.time()
    
    df_cell_train = df_train[(df_train.grid_x == grid_x)&(df_train.grid_y == grid_y)]
    place_counts = df_cell_train.place_id.value_counts()
    mask = (place_counts[df_cell_train.place_id.values] >= th).values
    df_cell_train = df_cell_train.loc[mask]
    
    df_cell_test = df_test[(df_test.grid_x == grid_x)&(df_test.grid_y == grid_y)]
    row_ids = df_cell_test.row_id
    
    #Applying the classifier
    clf = KNeighborsClassifier(n_neighbors=NNeighbors, weights='distance', 
                               metric='manhattan')
    clf.fit(df_cell_train[feature_list], df_cell_train.place_id)
    predictions = clf.predict_proba(df_cell_test[feature_list])
    result_index = np.argsort(predictions, axis=1)[:,::-1][:,:3]
    result = pd.DataFrame(df_cell_test.row_id)
    result['p1'] = clf.classes_[result_index][:,:1]
    result['p2'] = clf.classes_[result_index][:,1:2]
    result['p3'] = clf.classes_[result_index][:,2:3]
    
    return result

# %%
def run_validation():
    # Run validation
    df_train = pd.read_csv('../train.csv',
                           usecols=['row_id','x','y','time','place_id'])
    
    df_valiation = df_train[df_train.time > 786239 * 0.875]
    
    df_train = df_train[df_train.time <= 786239 * 0.875]
    
    n_cell_x = 10
    n_cell_y = 20 
    
    print('Preparing train data', flush=True)
    df_train = prepare_data(df_train, n_cell_x, n_cell_y)
    df_valiation = prepare_data(df_valiation, n_cell_x, n_cell_y)
    df_valiation['p1'] = np.nan
    df_valiation['p2'] = np.nan
    df_valiation['p3'] = np.nan
    
    prediction_result = run_prediction(df_train, df_valiation, n_cell_x, n_cell_y, 5)
    
    # Calculate score
    prediction_result.sort_index(inplace=True)
    prediction_result['score'] = (prediction_result.p1 == df_valiation.place_id) * 1
    prediction_result['score'] += (prediction_result.p2 == df_valiation.place_id) * 0.5
    prediction_result['score'] += (prediction_result.p3 == df_valiation.place_id) * 0.33
    
    print(prediction_result.score.describe(), flush=True)

# %%
NNeighbors = 15
run_validation()

NNeighbors = 20
run_validation()

NNeighbors = 25
run_validation()

NNeighbors = 30
run_validation()

NNeighbors = 35
run_validation()

NNeighbors = 40
run_validation()

NNeighbors = 45
run_validation()

NNeighbors = 50
run_validation()
# Out:
# Preparing train data
# Elapsed time overall: 44.42288374900818 seconds 0
# Elapsed time overall: 46.075960636138916 seconds 1
# Elapsed time overall: 48.83182239532471 seconds 2
# Elapsed time overall: 48.09553337097168 seconds 3
# Elapsed time overall: 48.275872468948364 seconds 4
# Elapsed time overall: 50.01570725440979 seconds 5
# Elapsed time overall: 47.48982810974121 seconds 6
# Elapsed time overall: 50.71571636199951 seconds 7
# Elapsed time overall: 47.42844605445862 seconds 8
# Elapsed time overall: 42.66829967498779 seconds 9
# count    4417684.000000
# mean           0.527468
# std            0.456938
# min            0.000000
# 25%            0.000000
# 50%            0.500000
# 75%            1.000000
# max            1.000000
# Name: score, dtype: float64
# Preparing train data
# Elapsed time overall: 45.36300230026245 seconds 0
# Elapsed time overall: 42.246015548706055 seconds 1
# Elapsed time overall: 51.92838501930237 seconds 2
# Elapsed time overall: 48.56256055831909 seconds 3
# Elapsed time overall: 49.1607940196991 seconds 4
# Elapsed time overall: 50.9369683265686 seconds 5
# Elapsed time overall: 48.91799736022949 seconds 6
# Elapsed time overall: 52.03406524658203 seconds 7
# Elapsed time overall: 51.816566944122314 seconds 8
# Elapsed time overall: 43.355175733566284 seconds 9
# count    4417684.000000
# mean           0.531935
# std            0.454842
# min            0.000000
# 25%            0.000000
# 50%            0.500000
# 75%            1.000000
# max            1.000000
# Name: score, dtype: float64
# Preparing train data
# Elapsed time overall: 41.59596920013428 seconds 0
# Elapsed time overall: 42.339914083480835 seconds 1
# Elapsed time overall: 56.00734090805054 seconds 2
# Elapsed time overall: 54.871670961380005 seconds 3
# Elapsed time overall: 51.30979609489441 seconds 4
# Elapsed time overall: 53.7941038608551 seconds 5
# Elapsed time overall: 52.62331295013428 seconds 6
# Elapsed time overall: 53.56741142272949 seconds 7
# Elapsed time overall: 52.103508710861206 seconds 8
# Elapsed time overall: 46.52507400512695 seconds 9
# count    4417684.000000
# mean           0.533805
# std            0.453489
# min            0.000000
# 25%            0.000000
# 50%            0.500000
# 75%            1.000000
# max            1.000000
# Name: score, dtype: float64
# Preparing train data
# Elapsed time overall: 45.62649703025818 seconds 0
# Elapsed time overall: 44.607216596603394 seconds 1
# Elapsed time overall: 54.43902778625488 seconds 2
# Elapsed time overall: 54.03521513938904 seconds 3
# Elapsed time overall: 55.500805377960205 seconds 4
# Elapsed time overall: 56.77850317955017 seconds 5
# Elapsed time overall: 55.819313764572144 seconds 6
# Elapsed time overall: 56.6769118309021 seconds 7
# Elapsed time overall: 55.996838092803955 seconds 8
# Elapsed time overall: 48.45962619781494 seconds 9
# count    4417684.000000
# mean           0.534364
# std            0.452581
# min            0.000000
# 25%            0.000000
# 50%            0.500000
# 75%            1.000000
# max            1.000000
# Name: score, dtype: float64
# Preparing train data
# Elapsed time overall: 50.114726066589355 seconds 0
# Elapsed time overall: 49.043360471725464 seconds 1
# Elapsed time overall: 60.38594126701355 seconds 2
# Elapsed time overall: 56.331247091293335 seconds 3
# Elapsed time overall: 57.975085496902466 seconds 4
# Elapsed time overall: 61.02731490135193 seconds 5
# Elapsed time overall: 57.53414487838745 seconds 6
# Elapsed time overall: 59.442471742630005 seconds 7
# Elapsed time overall: 56.24909424781799 seconds 8
# Elapsed time overall: 53.168670654296875 seconds 9
# count    4417684.000000
# mean           0.534388
# std            0.451947
# min            0.000000
# 25%            0.000000
# 50%            0.500000
# 75%            1.000000
# max            1.000000
# Name: score, dtype: float64
# Preparing train data
# Elapsed time overall: 50.303494930267334 seconds 0
# Elapsed time overall: 57.949676752090454 seconds 1
# Elapsed time overall: 61.541441202163696 seconds 2
# Elapsed time overall: 58.174426794052124 seconds 3
# Elapsed time overall: 59.993305683135986 seconds 4
# Elapsed time overall: 61.36531138420105 seconds 5
# Elapsed time overall: 59.37049913406372 seconds 6
# Elapsed time overall: 61.87305045127869 seconds 7
# Elapsed time overall: 59.429290771484375 seconds 8
# Elapsed time overall: 50.90167450904846 seconds 9
# count    4417684.000000
# mean           0.533968
# std            0.451495
# min            0.000000
# 25%            0.000000
# 50%            0.500000
# 75%            1.000000
# max            1.000000
# Name: score, dtype: float64
# Preparing train data
# Elapsed time overall: 57.022464990615845 seconds 0
# Elapsed time overall: 58.72410869598389 seconds 1
# Elapsed time overall: 64.90319800376892 seconds 2
# Elapsed time overall: 62.27644681930542 seconds 3
# Elapsed time overall: 61.520485162734985 seconds 4
# Elapsed time overall: 62.96897530555725 seconds 5
# Elapsed time overall: 61.39191651344299 seconds 6
# Elapsed time overall: 64.80646419525146 seconds 7
# Elapsed time overall: 63.15328645706177 seconds 8
# Elapsed time overall: 55.06453776359558 seconds 9
# count    4417684.000000
# mean           0.533419
# std            0.451173
# min            0.000000
# 25%            0.000000
# 50%            0.500000
# 75%            1.000000
# max            1.000000
# Name: score, dtype: float64
# Preparing train data
# Elapsed time overall: 56.8941912651062 seconds 0
# Elapsed time overall: 62.12465715408325 seconds 1
# Elapsed time overall: 65.85756063461304 seconds 2
# Elapsed time overall: 64.73236846923828 seconds 3
# Elapsed time overall: 61.837106227874756 seconds 4
# Elapsed time overall: 66.49509334564209 seconds 5
# Elapsed time overall: 63.723565101623535 seconds 6
# Elapsed time overall: 68.83833861351013 seconds 7
# Elapsed time overall: 59.744580030441284 seconds 8
# Elapsed time overall: 54.72152614593506 seconds 9
# count    4417684.000000
# mean           0.532674
# std            0.450891
# min            0.000000
# 25%            0.000000
# 50%            0.500000
# 75%            1.000000
# max            1.000000
# Name: score, dtype: float64

# %% [markdown]
# Neighbors, score <br/>
# 15   0.527468 <br/>
# 20   0.531935 <br/>
# 25   0.533805 <br/>
# 30   0.534364 <br/>
# 35   0.534388 <br/>
# 40   0.533968 <br/>
# 45   0.533419 <br/>
# 50   0.532674 <br/>

# %%
# Write to file
prediction_result['place_id'] = prediction_result.p1.astype(str) + " " + \
                                 prediction_result.p2.astype(str) + " " + \
                                 prediction_result.p3.astype(str)
prediction_result[['row_id', 'place_id']].to_csv('validation_result.csv', index=False)

# %%
# Run test
df_train = pd.read_csv('../train.csv',
                       usecols=['row_id','x','y','time','place_id'])
df_test = pd.read_csv('../test.csv',
                       usecols=['row_id','x','y','time'])
n_cell_x = 10
n_cell_y = 20 

df_train = prepare_data(df_train, n_cell_x, n_cell_y)
df_test = prepare_data(df_test, n_cell_x, n_cell_y)
df_test['p1'] = np.nan
df_test['p2'] = np.nan
df_test['p3'] = np.nan
prediction_result = run_prediction(df_train, df_test, 5)

prediction_result.sort_index(inplace=True)
prediction_result['place_id'] = prediction_result.p1.astype(str) + " " + \
                                 prediction_result.p2.astype(str) + " " + \
                                 prediction_result.p3.astype(str)
prediction_result[['row_id', 'place_id']].to_csv('result.csv', index=False)
