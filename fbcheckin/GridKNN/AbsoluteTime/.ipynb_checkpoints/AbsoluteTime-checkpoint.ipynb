# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import time

# %%
feature_list = ['x','y','hour','weekday','day','month','year', 'accuracy', 'log_month']

# %%
def prepare_data(df, n_cell_x, n_cell_y):
    #Creating the grid
    size_x = 10. / n_cell_x
    size_y = 10. / n_cell_y
    eps = 0.00001  
    xs = np.where(df.x.values < eps, 0, df.x.values - eps)
    ys = np.where(df.y.values < eps, 0, df.y.values - eps)
    pos_x = (xs / size_x).astype(np.int)
    pos_y = (ys / size_y).astype(np.int)
    df['grid_x'] = pos_x
    df['grid_y'] = pos_y
    
    df.x = df.x.values * fw[0]
    df.y = df.y.values * fw[1]
    initial_date = np.datetime64('2014-01-01T01:01', dtype='datetime64[m]') 
    d_times = pd.DatetimeIndex(initial_date + np.timedelta64(int(mn), 'm') 
                               for mn in df.time.values)    
    df['hour'] = (d_times.hour+ d_times.minute/60) * fw[2]
    df['weekday'] = d_times.weekday * fw[3]
    df['day'] = (d_times.dayofyear * fw[4]).astype(int)
    df['month'] = d_times.month * fw[5]
    df['year'] = (d_times.year - 2013) * fw[6]
    df.accuracy = df.accuracy.values * fw[7]
    df['log_month'] = np.log10(3+df.time/(60 * 24 * 30)) * fw[8]
    
    df = df.drop(['time'], axis=1)
    
    return df

# %%
def run_prediction(df_train, df_test, n_cell_x, n_cell_y, th):
    total_result = pd.DataFrame()
    for x_grid in range(0, n_cell_x):
        start_time = time.time()
        for y_grid in range(0, n_cell_y):
            total_result = total_result.append(process_one_cell(df_train, df_test, x_grid, y_grid, th))
        print("Elapsed time overall: %s seconds" % (time.time() - start_time), x_grid, flush = True)
    return total_result

# %%
def process_one_cell(df_train, df_test, grid_x, grid_y, th):
    start_time = time.time()
    
    df_cell_train = df_train[((df_train.grid_x == grid_x)&(df_train.grid_y == grid_y))]# |
    '''
                             ((df_train.grid_x == grid_x)&(df_train.grid_y == grid_y + 1)) |
                             ((df_train.grid_x == grid_x)&(df_train.grid_y == grid_y - 1)) |
                             ((df_train.grid_x == grid_x + 1)&(df_train.grid_y == grid_y)) |
                             ((df_train.grid_x == grid_x + 1)&(df_train.grid_y == grid_y + 1)) |
                             ((df_train.grid_x == grid_x + 1)&(df_train.grid_y == grid_y - 1)) |
                             ((df_train.grid_x == grid_x - 1)&(df_train.grid_y == grid_y)) |
                             ((df_train.grid_x == grid_x - 1)&(df_train.grid_y == grid_y + 1)) |
                             ((df_train.grid_x == grid_x - 1)&(df_train.grid_y == grid_y - 1))]
    '''
    place_counts = df_cell_train.place_id.value_counts()
    mask = (place_counts[df_cell_train.place_id.values] >= th).values
    df_cell_train = df_cell_train.loc[mask]
    
    df_cell_test = df_test[(df_test.grid_x == grid_x)&(df_test.grid_y == grid_y)]
    row_ids = df_cell_test.row_id
    
    #Applying the classifier
    clf = KNeighborsClassifier(n_neighbors=35, weights='distance', 
                               metric='manhattan')
    clf.fit(df_cell_train[feature_list], df_cell_train.place_id)
    predictions = clf.predict_proba(df_cell_test[feature_list])
    result_index = np.argsort(predictions, axis=1)[:,::-1][:,:3]
    result = pd.DataFrame(df_cell_test.row_id)
    result['p1'] = clf.classes_[result_index][:,:1]
    result['p2'] = clf.classes_[result_index][:,1:2]
    result['p3'] = clf.classes_[result_index][:,2:3]
    
    return result

# %%
def run_validation():
    # Run validation
    df_train = pd.read_csv('../../train.csv',
                               usecols=['row_id','x','y','accuracy','time','place_id'])
    
    df_valiation = df_train[df_train.time > 786239 * 0.875]
    
    df_train = df_train[df_train.time <= 786239 * 0.875]
    
    n_cell_x = 10
    n_cell_y = 20 
    
    print('Preparing train data')
    df_train = prepare_data(df_train, n_cell_x, n_cell_y)
    df_valiation = prepare_data(df_valiation, n_cell_x, n_cell_y)
    df_valiation['p1'] = np.nan
    df_valiation['p2'] = np.nan
    df_valiation['p3'] = np.nan
    
    prediction_result = run_prediction(df_train, df_valiation, n_cell_x, n_cell_y, 5)
    
    # Calculate score
    prediction_result.sort_index(inplace=True)
    prediction_result['score'] = (prediction_result.p1 == df_valiation.place_id) * 1
    prediction_result['score'] += (prediction_result.p2 == df_valiation.place_id) * 0.5
    prediction_result['score'] += (prediction_result.p3 == df_valiation.place_id) * 0.33
    
    print(prediction_result.score.describe(), flush=True)

# %%
#     x    y     hour weekday day     month year  accuracy log month
fw = [400, 1000, 4,   3.5,    1./22., 2,    9,    0.09,    2]
run_validation()

#     x    y     hour weekday day     month year  accuracy log month
fw = [400, 1000, 4,   3.5,    1./22., 2,    9,    0.09,    3]
run_validation()

#     x    y     hour weekday day     month year  accuracy log month
fw = [400, 1000, 4,   3.5,    1./22., 2,    9,    0.09,    4]
run_validation()

#     x    y     hour weekday day     month year  accuracy log month
fw = [400, 1000, 4,   3.5,    1./22., 2,    9,    0.09,    4.5]
run_validation()

#     x    y     hour weekday day     month year  accuracy log month
fw = [400, 1000, 4,   3.5,    1./22., 2,    9,    0.09,    5.5]
run_validation()

#     x    y     hour weekday day     month year  accuracy log month
fw = [400, 1000, 4,   3.5,    1./22., 2,    9,    0.09,    6]
run_validation()

#     x    y     hour weekday day     month year  accuracy log month
fw = [400, 1000, 4,   3.5,    1./22., 2,    9,    0.09,    7]
run_validation()
# Out:
# Preparing train data
# Elapsed time overall: 94.23936367034912 seconds 0
# Elapsed time overall: 102.71740794181824 seconds 1
# Elapsed time overall: 102.294260263443 seconds 2
# Elapsed time overall: 96.05930304527283 seconds 3
# Elapsed time overall: 97.92958474159241 seconds 4
# Elapsed time overall: 102.7749388217926 seconds 5
# Elapsed time overall: 98.24434089660645 seconds 6
# Elapsed time overall: 103.0022873878479 seconds 7
# Elapsed time overall: 105.19660592079163 seconds 8
# Elapsed time overall: 91.59485745429993 seconds 9
# count    4417684.000000
# mean           0.539606
# std            0.451221
# min            0.000000
# 25%            0.000000
# 50%            0.500000
# 75%            1.000000
# max            1.000000
# Name: score, dtype: float64
# Preparing train data
# Elapsed time overall: 109.33655905723572 seconds 0
# Elapsed time overall: 103.28286242485046 seconds 1
# Elapsed time overall: 106.13002228736877 seconds 2
# Elapsed time overall: 107.53942537307739 seconds 3
# Elapsed time overall: 105.88021636009216 seconds 4
# Elapsed time overall: 107.70791625976562 seconds 5
# Elapsed time overall: 107.61737966537476 seconds 6
# Elapsed time overall: 103.25110459327698 seconds 7
# Elapsed time overall: 89.22821712493896 seconds 8
# Elapsed time overall: 89.69720792770386 seconds 9
# count    4417684.000000
# mean           0.539601
# std            0.451204
# min            0.000000
# 25%            0.000000
# 50%            0.500000
# 75%            1.000000
# max            1.000000
# Name: score, dtype: float64
# Preparing train data
# Elapsed time overall: 96.55300760269165 seconds 0
# Elapsed time overall: 98.5822286605835 seconds 1
# Elapsed time overall: 114.03358697891235 seconds 2
# Elapsed time overall: 104.97630977630615 seconds 3
# Elapsed time overall: 108.50602412223816 seconds 4
# Elapsed time overall: 124.24039268493652 seconds 5
# Elapsed time overall: 121.37795352935791 seconds 6
# Elapsed time overall: 134.90152072906494 seconds 7
# Elapsed time overall: 127.95814538002014 seconds 8
# Elapsed time overall: 116.01909327507019 seconds 9
# count    4417684.000000
# mean           0.539620
# std            0.451172
# min            0.000000
# 25%            0.000000
# 50%            0.500000
# 75%            1.000000
# max            1.000000
# Name: score, dtype: float64
# Preparing train data
# Elapsed time overall: 116.77239441871643 seconds 0
# Elapsed time overall: 124.59329724311829 seconds 1
# Elapsed time overall: 130.32982563972473 seconds 2
# Elapsed time overall: 128.0588481426239 seconds 3
# Elapsed time overall: 129.47421264648438 seconds 4
# Elapsed time overall: 122.76272130012512 seconds 5
# Elapsed time overall: 123.9399242401123 seconds 6
# Elapsed time overall: 130.6778962612152 seconds 7
# Elapsed time overall: 128.51228141784668 seconds 8
# Elapsed time overall: 115.54834294319153 seconds 9
# count    4417684.000000
# mean           0.539621
# std            0.451160
# min            0.000000
# 25%            0.000000
# 50%            0.500000
# 75%            1.000000
# max            1.000000
# Name: score, dtype: float64
# Preparing train data
# Elapsed time overall: 96.81885170936584 seconds 0
# Elapsed time overall: 99.68858933448792 seconds 1
# Elapsed time overall: 111.61978340148926 seconds 2
# Elapsed time overall: 107.25684404373169 seconds 3
# Elapsed time overall: 112.15707755088806 seconds 4
# Elapsed time overall: 126.5023717880249 seconds 5
# Elapsed time overall: 123.77431273460388 seconds 6
# Elapsed time overall: 133.4420998096466 seconds 7
# Elapsed time overall: 134.47661232948303 seconds 8
# Elapsed time overall: 118.49257493019104 seconds 9
# count    4417684.000000
# mean           0.539590
# std            0.451137
# min            0.000000
# 25%            0.000000
# 50%            0.500000
# 75%            1.000000
# max            1.000000
# Name: score, dtype: float64
# Preparing train data
# Elapsed time overall: 120.44020915031433 seconds 0
# Elapsed time overall: 130.01978039741516 seconds 1
# Elapsed time overall: 134.174489736557 seconds 2
# Elapsed time overall: 129.14103269577026 seconds 3
# Elapsed time overall: 128.8279004096985 seconds 4
# Elapsed time overall: 124.45948672294617 seconds 5
# Elapsed time overall: 123.19374227523804 seconds 6
# Elapsed time overall: 131.79631280899048 seconds 7
# Elapsed time overall: 132.81316208839417 seconds 8
# Elapsed time overall: 114.13583064079285 seconds 9
# count    4417684.000000
# mean           0.539566
# std            0.451140
# min            0.000000
# 25%            0.000000
# 50%            0.500000
# 75%            1.000000
# max            1.000000
# Name: score, dtype: float64
# Preparing train data
# Elapsed time overall: 114.86493372917175 seconds 0
# Elapsed time overall: 121.67333912849426 seconds 1
# Elapsed time overall: 129.29309701919556 seconds 2
# Elapsed time overall: 123.88574838638306 seconds 3
# Elapsed time overall: 132.80812692642212 seconds 4
# Elapsed time overall: 151.77414560317993 seconds 5
# Elapsed time overall: 158.84465670585632 seconds 6
# Elapsed time overall: 155.62130427360535 seconds 7
# Elapsed time overall: 154.27737998962402 seconds 8
# Elapsed time overall: 137.45580649375916 seconds 9
# count    4417684.000000
# mean           0.539455
# std            0.451107
# min            0.000000
# 25%            0.000000
# 50%            0.500000
# 75%            1.000000
# max            1.000000
# Name: score, dtype: float64

# %% [markdown]
# 0.1 0.539393
# 0.5 0.539439
# 1   0.539493
# 2   0.539606
# 3   0.539601
# 4   0.539620
# 4.5 0.539621   <--- choice
# 5   0.539611
# 5.5 0.539590
# 6   0.539566
# 7   0.539455
# 10  0.538991
# 20  0.535883
# 50  0.521477

# %% [markdown]
# Validation result:

# %%
# Write to file
prediction_result['place_id'] = prediction_result.p1.astype(str) + " " + \
                                 prediction_result.p2.astype(str) + " " + \
                                 prediction_result.p3.astype(str)
prediction_result[['row_id', 'place_id']].to_csv('new_baseline_validation_result.csv', index=False)

# %%
# Run test
df_train = pd.read_csv('../../train.csv',
                       usecols=['row_id','x','y','accuracy','time','place_id'])
df_test = pd.read_csv('../../test.csv',
                       usecols=['row_id','x','y','accuracy','time'])
n_cell_x = 30
n_cell_y = 60 

df_train = prepare_data(df_train, n_cell_x, n_cell_y)
df_test = prepare_data(df_test, n_cell_x, n_cell_y)
df_test['p1'] = np.nan
df_test['p2'] = np.nan
df_test['p3'] = np.nan
prediction_result = run_prediction(df_train, df_test, 5)

prediction_result.sort_index(inplace=True)
prediction_result['place_id'] = prediction_result.p1.astype(str) + " " + \
                                 prediction_result.p2.astype(str) + " " + \
                                 prediction_result.p3.astype(str)
prediction_result[['row_id', 'place_id']].to_csv('new_baseline_result.csv', index=False)
