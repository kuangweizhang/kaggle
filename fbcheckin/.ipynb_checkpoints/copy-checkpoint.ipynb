# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime

# %%
train_set = pd.read_csv('train.csv')
test_set = pd.read_csv('test.csv', skiprows = 0, nrows=300000)

# %%
for i in range(0,24):
    test_set['placeId' + str(i)] = np.nan
    test_set['score' + str(i)] = np.nan

# %%
counter = 0;
print(str(counter) + ' ' + str(datetime.now()), flush = True)
for row in test_set.itertuples():
    neighbors = train_set[(train_set.y > row.y - 0.01) & \
                          (train_set.y < row.y + 0.01) & \
                          (train_set.x > row.x - 0.02) & \
                          (train_set.x < row.x + 0.02)]
    counts = neighbors.place_id.value_counts()
    i = 0
    for index in counts.index:
        test_set.set_value(row.Index, 'placeId' + str(i), index) 
        test_set.set_value(row.Index, 'score' + str(i), counts[index])
        i = i + 1
        if(i == 25):
            break
    counter += 1
    if(counter % 10 == 0):
        print(str(counter) + ' ' + str(datetime.now()), flush = True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-bf19e1ef8c82> in <module>()
#       1 counter = 0;
#       2 for row in test_set.itertuples():
# ----> 3     neighbors = train_set[(train_set.y > row.y - 0.01) &                           (train_set.y < row.y + 0.01) &                           (train_set.x > row.x - 0.02) &                           (train_set.x < row.x + 0.02)]
#       4     counts = neighbors.place_id.value_counts()
#       5     i = 0
#
# C:\Users\Kuangwei\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other)
#     786             return filler(self._constructor(na_op(self.values, other.values),
#     787                                      index=self.index,
# --> 788                                      name=name))
#     789
#     790         elif isinstance(other, pd.DataFrame):
#
# C:\Users\Kuangwei\Anaconda3\lib\site-packages\pandas\core\ops.py in <lambda>(x)
#     775
#     776         fill_int = lambda x: x.fillna(0)
# --> 777         fill_bool = lambda x: x.fillna(False).astype(bool)
#     778
#     779         if isinstance(other, pd.Series):
#
# C:\Users\Kuangwei\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, raise_on_error, **kwargs)
#    2630
#    2631         mgr = self._data.astype(
# -> 2632             dtype=dtype, copy=copy, raise_on_error=raise_on_error, **kwargs)
#    2633         return self._constructor(mgr).__finalize__(self)
#    2634
#
# C:\Users\Kuangwei\Anaconda3\lib\site-packages\pandas\core\internals.py in astype(self, dtype, **kwargs)
#    2862
#    2863     def astype(self, dtype, **kwargs):
# -> 2864         return self.apply('astype', dtype=dtype, **kwargs)
#    2865
#    2866     def convert(self, **kwargs):
#
# C:\Users\Kuangwei\Anaconda3\lib\site-packages\pandas\core\internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    2821
#    2822             kwargs['mgr'] = self
# -> 2823             applied = getattr(b, f)(**kwargs)
#    2824             result_blocks = _extend_blocks(applied, result_blocks)
#    2825
#
# C:\Users\Kuangwei\Anaconda3\lib\site-packages\pandas\core\internals.py in astype(self, dtype, copy, raise_on_error, values, **kwargs)
#     428     def astype(self, dtype, copy=False, raise_on_error=True, values=None, **kwargs):
#     429         return self._astype(dtype, copy=copy, raise_on_error=raise_on_error,
# --> 430                             values=values, **kwargs)
#     431
#     432     def _astype(self, dtype, copy=False, raise_on_error=True, values=None,
#
# C:\Users\Kuangwei\Anaconda3\lib\site-packages\pandas\core\internals.py in _astype(self, dtype, copy, raise_on_error, values, klass, mgr, **kwargs)
#     446         if self.dtype == dtype:
#     447             if copy:
# --> 448                 return self.copy()
#     449             return self
#     450
#
# C:\Users\Kuangwei\Anaconda3\lib\site-packages\pandas\core\internals.py in copy(self, deep, mgr)
#     576         values = self.values
#     577         if deep:
# --> 578             values = values.copy()
#     579         return self.make_block(values,
#     580                                klass=self.__class__,
#
# KeyboardInterrupt:

# %%
test_set[test_set]
# Out:
#         row_id       x       y  accuracy    time    placeId0  score0  \
# 0            0  0.1675  1.3608       107  930883  7652380351      26
# 1            1  7.3909  2.5301        35  893017  4505710601      23
# 2            2  8.0978  2.3473        62  976933  7862615088      44
# 3            3  0.9990  1.0591        62  907285  7995458948     318
# 4            4  0.6670  9.7254        40  914399  4764406629     137
# 5            5  0.1771  0.0022       161  814077  8370753254     169
# 6            6  5.5299  4.6581         2  930759  7564010400     190
# 7            7  8.6021  3.1744         4  862115  1254473002      41
# 8            8  4.2250  6.3435       162  787391  6470278079      58
# 9            9  0.6489  6.2611        39  793166  3894834079     118
# 10          10  2.7546  6.6373       315  807936  1776286518     223
# 11          11  0.9998  7.4121        80  913991  6329683508      39
# 12          12  4.9477  6.4959         7  938599  9031150064     149
# 13          13  5.0336  1.2666        83  800780  5313553144     127
# 14          14  0.9480  4.4362        59  892117  7405695170     164
# 15          15  0.2898  3.0031        57  909801  4390687315     428
# 16          16  5.2386  1.8262        52  867042  8015849918     534
# 17          17  2.9797  7.7333       170  822650  8792019238     110
# 18          18  5.0956  0.1904        56  841934  2865997311      64
# 19          19  2.7856  1.7072        61  884954  8151914846     393
# 20          20  3.6321  2.2853        67  905857  5937599993      36
# 21          21  9.9039  5.9419        76  842668  4289747407      76
# 22          22  5.5745  3.4077        30  863513  7840467506     141
# 23          23  2.4119  6.3321        70  867179  9882666614     104
# 24          24  3.0635  4.2433        78  855147  9366346488      34
# 25          25  4.8934  3.7615       237  820307  7563100425     391
# 26          26  0.9999  9.9553       844  809976  4911383584      21
# 27          27  9.4647  2.0808       638  872145  8977862655     250
# 28          28  5.0168  6.4633        90  861390  4070072518      19
# 29          29  0.1378  6.3284        25  791750  7441010909      95
# ...        ...     ...     ...       ...     ...         ...     ...
# 299970  299970  3.4725  4.5019       101  844460         NaN     NaN
# 299971  299971  2.0133  5.2200        97  994683         NaN     NaN
# 299972  299972  2.2387  7.6594        42  971895         NaN     NaN
# 299973  299973  8.1372  8.7265        10  971034         NaN     NaN
# 299974  299974  6.3395  2.4597       164  898091         NaN     NaN
# 299975  299975  7.3019  4.3324        57  837737         NaN     NaN
# 299976  299976  5.7875  0.8124       155  869516         NaN     NaN
# 299977  299977  4.9330  7.1891        63  994396         NaN     NaN
# 299978  299978  5.3107  3.5688        57  879257         NaN     NaN
# 299979  299979  6.2979  4.0171        42  851025         NaN     NaN
# 299980  299980  8.8017  9.7912        61  902605         NaN     NaN
# 299981  299981  7.3002  4.8817       304  904935         NaN     NaN
# 299982  299982  5.3289  1.5191       274  802651         NaN     NaN
# 299983  299983  8.8891  2.2512       108  957462         NaN     NaN
# 299984  299984  3.9172  5.0765        63  879266         NaN     NaN
# 299974         NaN      NaN         NaN      NaN         NaN      NaN
# 299975         NaN      NaN         NaN      NaN         NaN      NaN
# 299976         NaN      NaN         NaN      NaN         NaN      NaN
# 299977         NaN      NaN         NaN      NaN         NaN      NaN
# 299978         NaN      NaN         NaN      NaN         NaN      NaN
# 299979         NaN      NaN         NaN      NaN         NaN      NaN
# 299980         NaN      NaN         NaN      NaN         NaN      NaN
# 299981         NaN      NaN         NaN      NaN         NaN      NaN
# 299982         NaN      NaN         NaN      NaN         NaN      NaN
# 299983         NaN      NaN         NaN      NaN         NaN      NaN
# 299984         NaN      NaN         NaN      NaN         NaN      NaN
# 299985         NaN      NaN         NaN      NaN         NaN      NaN
# 299986         NaN      NaN         NaN      NaN         NaN      NaN
# 299987         NaN      NaN         NaN      NaN         NaN      NaN
# 299988         NaN      NaN         NaN      NaN         NaN      NaN
# 299989         NaN      NaN         NaN      NaN         NaN      NaN
# 299990         NaN      NaN         NaN      NaN         NaN      NaN
# 299991         NaN      NaN         NaN      NaN         NaN      NaN
# 299992         NaN      NaN         NaN      NaN         NaN      NaN
# 299993         NaN      NaN         NaN      NaN         NaN      NaN
# 299994         NaN      NaN         NaN      NaN         NaN      NaN
# 299995         NaN      NaN         NaN      NaN         NaN      NaN
# 299996         NaN      NaN         NaN      NaN         NaN      NaN
# 299997         NaN      NaN         NaN      NaN         NaN      NaN
# 299998         NaN      NaN         NaN      NaN         NaN      NaN
# 299999         NaN      NaN         NaN      NaN         NaN      NaN
#
#          placeId24  score24
# 0              NaN      NaN
# 1       3500983798        1
# 2       5232589767        1
# 3       9522876320        1
# 4       5643258248        1
# 5              NaN      NaN
# 6       5397831197        1
# 7       6973492609        1
# 8       9114410829        1
# 9       5206010466        1
# 10      4586965148        1
# 11      8275556088        1
# 12      1161453673        1
# 13      4622847381        1
# 14      5150369474        1
# 15      6683833689        1
# 16      6182322007        1
# 17      5783844343        1
# 18      6660617304        1
# 19      1082115297        1
# 20      1441208082        1
# 21      3963901891        1
# 22      6384989877        1
# 23      8419986595        1
# 24      4308373031        1
# 25      5971362180        1
# 26      4305677151        1
# 27      3703751779        1
# 28      7096046537        1
# 29      5418779431        1
# ...            ...      ...
# 299970         NaN      NaN
# 299971         NaN      NaN
# 299972         NaN      NaN
# 299973         NaN      NaN
# 299974         NaN      NaN
# 299975         NaN      NaN
# 299976         NaN      NaN
# 299977         NaN      NaN
# 299978         NaN      NaN
# 299979         NaN      NaN
# 299980         NaN      NaN
# 299981         NaN      NaN
# 299982         NaN      NaN
# 299983         NaN      NaN
# 299984         NaN      NaN
# 299985         NaN      NaN
# 299986         NaN      NaN
# 299987         NaN      NaN
# 299988         NaN      NaN
# 299989         NaN      NaN
# 299990         NaN      NaN
# 299991         NaN      NaN
# 299992         NaN      NaN
# 299993         NaN      NaN
# 299994         NaN      NaN
# 299995         NaN      NaN
# 299996         NaN      NaN
# 299997         NaN      NaN
# 299998         NaN      NaN
# 299999         NaN      NaN
#
# [300000 rows x 55 columns]
