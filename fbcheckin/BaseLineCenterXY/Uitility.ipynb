# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime

# %%
part1_result = pd.read_csv('part1.csv')
part2_result = pd.read_csv('part2.csv')
part3_result = pd.read_csv('part3.csv')
part4_result = pd.read_csv('part4.csv')

# %%
part1_result.head()
# Out:
#    row_id                           place_id
# 0       0   7652380351 3831655216 6253981821
# 1       3   7995458948 3243409743 8393706174
# 2       5   8370753254 9727638738 8556108428
# 3      14   3756584599 7405695170 7802057913
# 4      15   4390687315 2437541306 8442351461

# %%
final_result = pd.concat([part1_result, part2_result, part3_result, part4_result])

# %%
final_result_sorted = final_result.sort_values(['row_id'])z

# %%
final_result_sorted
# Out:
#           row_id                           place_id
# 0              0   7652380351 3831655216 6253981821
# 0              1   9801651394 5801740503 2465239230
# 1              2   7862615088 2516481553 2653128693
# 1              3   7995458948 3243409743 8393706174
# 0              4   4764406629 8277155346 8711861736
# 2              5   8370753254 9727638738 8556108428
# 2              6   7283245557 3165318731 7564010400
# 3              7   2482334547 2247481267 4346049470
# 1              8   6421756522 6470278079 1496969742
# 2              9   3894834079 6980929490 2028638270
# 3             10   1776286518 8209128517 3641802545
# 4             11   5011847413 6955556885 4785518658
# 5             12   9031150064 4000363114 6291666280
# 4             13   5313553144 2434531540 3420992015
# 3             14   3756584599 7405695170 7802057913
# 4             15   4390687315 2437541306 8442351461
# 5             16   8015849918 6368539484 9440230828
# ...

# %%
final_result_sorted.index = np.arange(0,8607058)

# %%
final_result_sorted
# Out:
#           row_id                           place_id
# 0              0   7652380351 3831655216 6253981821
# 1              1   9801651394 5801740503 2465239230
# 2              2   7862615088 2516481553 2653128693
# 3              3   7995458948 3243409743 8393706174
# 4              4   4764406629 8277155346 8711861736
# 5              5   8370753254 9727638738 8556108428
# 6              6   7283245557 3165318731 7564010400
# 7              7   2482334547 2247481267 4346049470
# 8              8   6421756522 6470278079 1496969742
# 9              9   3894834079 6980929490 2028638270
# 10            10   1776286518 8209128517 3641802545
# 11            11   5011847413 6955556885 4785518658
# 12            12   9031150064 4000363114 6291666280
# 13            13   5313553144 2434531540 3420992015
# 14            14   3756584599 7405695170 7802057913
# 15            15   4390687315 2437541306 8442351461
# 16            16   8015849918 6368539484 9440230828
# ...

# %%
final_result_sorted.to_csv('total.csv')
