# %%
import xgboost as xgb
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Out:
# /home/kevin/anaconda3/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
train = pd.read_json('./input/train.json')
test = pd.read_json("./input/test.json")

# %%
combined = pd.concat([train, test])

# %%
combined.latitude.describe()
# Out:
# count    124011.000000
# mean         40.737641
# std           0.744337
# min           0.000000
# 25%          40.728000
# 50%          40.751700
# 75%          40.774300
# max          44.883500
# Name: latitude, dtype: float64

# %%
combined.latitude.quantile(0.999)
# Out:
# 40.892000000000003

# %%
combined[combined.latitude > 41].sort_values(by = 'latitude')
# Out:
#         bathrooms  bedrooms                       building_id  \
# 61672         2.0         3  4bc28f3d8bd848ff5127f1bcf1130f3e
# 7338          2.5         4  7d80e00d60eff196fdfe82fa6d762746
# 5297          2.5         4  7d80e00d60eff196fdfe82fa6d762746
# 65745         1.0         2  501193b13b66775ca6798d37948c60b7
# 112696        1.0         1  69111122f465f6d186a7c750282b9d06
# 109644        2.0         2  69111122f465f6d186a7c750282b9d06
# 118154        1.0         1  69111122f465f6d186a7c750282b9d06
# 19157         1.0         1  69111122f465f6d186a7c750282b9d06
# 25135         2.0         2  69111122f465f6d186a7c750282b9d06
# 100346        1.0         1  e9f8fbe6cce51fe5e4418e1828bc6546
# 95913         2.0         3  f80820cec985c91749f57e6fcda37619
# 50867         1.0         1  636dab879ba37dd7dc3c23774306275c
# 88658         1.0         1  2053dfa936d1f5871d41a98cb4ce3a1b
# 18023         1.0         3  5f48394f3cf52d675ac9edafd75bb169
# ...

# %%
# Lattitute, anything larger than 41 is invalid

# %%
combined.latitude.quantile(0.001)
# Out:
# 40.575800000000001

# %%
combined[combined.latitude < 40.5000000000001].sort_values(by = 'latitude')
# Out:
#         bathrooms  bedrooms                       building_id  \
# 11348         1.0         3  f1833846e5f958df2a97e2b0258820e0
# 23825         1.0         3  f1833846e5f958df2a97e2b0258820e0
# 28197         1.0         1  a37f48a180071ce25f580ca5712d8101
# 32592         1.0         2  bf7acc01e1a2e227162c9b5a20b3c5ea
# 34487         1.0         1  d82a0ad657331e9de8ee5baa4f80ad81
# 43526         1.0         2  093b7b01eec2f7ae27cdc8275d62aecc
# 49362         1.0         0  86006c55bf5418d3c4c101a9259189a5
# 51400         1.0         2  51be50ef6f37759b07e4beff433b9219
# 53736         1.0         2  118611aca1e7ca05530cb1d577d0d0b5
# 58574         1.0         3  cf29cd8a079c451e356cc90f66eb4298
# 60891         1.0         1  2269f3b78be04190915e56bcea247ada
# 65830         1.0         2  3578e893915c225f540a8acca82ce127
# 66326         2.5         3  2726d3b13cf67a1090c0593b629fb35e
# 67390         1.0         2  9e9c52496a1be0899db1b4c2d31bb39f
# ...

# %%
# Lattitute, anything smaller than 40.5 is invalid

# %%
combined[(combined.latitude > 41) | (combined.latitude < 40.5)]
# Out:
#         bathrooms  bedrooms                       building_id  \
# 100346        1.0         1  e9f8fbe6cce51fe5e4418e1828bc6546
# 104822        1.0         0  437454e6d44ae7c94f60b1b6507d084a
# 106350        5.0         6                                 0
# 108994        1.0         0                                 0
# 109644        2.0         2  69111122f465f6d186a7c750282b9d06
# 114028        1.0         1  6869a3c2a96003e9992d6cd1c3c4b299
# 114889        2.0         2  2adec6e74a834940cde0f05a8684d08f
# 117255        1.0         1                                 0
# 121891        1.0         1  ebdf422b8605d69a719a5cdc34019463
# 16405         1.0         0  23b17bf6f7be64e3272b561cc0b65f5a
# 18023         1.0         3  5f48394f3cf52d675ac9edafd75bb169
# 18267         1.0         2                                 0
# 19157         1.0         1  69111122f465f6d186a7c750282b9d06
# 2028          1.0         1  1490317c3a31185f0c8115f01d1acc5b
# ...

# %%
combined.longitude.describe()
# Out:
# count    124011.000000
# mean        -73.949434
# std           1.372882
# min        -121.488000
# 25%         -73.991700
# 50%         -73.977800
# 75%         -73.954700
# max           0.000000
# Name: longitude, dtype: float64

# %%
combined.longitude.quantile(0.999)
# Out:
# -73.736599999999996

# %%
combined.longitude.quantile(0.001)
# Out:
# -74.036499000000006

# %%
combined.loc[(combined.longitude > -73.74) | (combined.longitude < -74.04)]
# Out:
#         bathrooms  bedrooms                       building_id  \
# 100140        1.0         2  920cbea4c790314471335c3a64496c9e
# 100346        1.0         1  e9f8fbe6cce51fe5e4418e1828bc6546
# 102756        1.0         0  abdc40a80dc42f32e02d10d3e629253e
# 104822        1.0         0  437454e6d44ae7c94f60b1b6507d084a
# 106350        5.0         6                                 0
# 108994        1.0         0                                 0
# 109507        3.0         3  95fabd330f806524ae62115264f1f840
# 109644        2.0         2  69111122f465f6d186a7c750282b9d06
# 113305        1.0         1  c391084ee341be0d85643b7bd1757993
# 113552        1.0         0  abdc40a80dc42f32e02d10d3e629253e
# 113599        1.0         0  abdc40a80dc42f32e02d10d3e629253e
# 114028        1.0         1  6869a3c2a96003e9992d6cd1c3c4b299
# 114889        2.0         2  2adec6e74a834940cde0f05a8684d08f
# 115801        1.0         2  fff0a02ad82421c226c6d6765a0dde57
# ...
